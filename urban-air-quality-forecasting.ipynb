# %% [markdown]
# <a href="https://colab.research.google.com/github/rahilAhmadi/urban-air-quality-forecasting/blob/master/urban-air-quality-forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# model 1
#
# # **Linear Regression**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.linear_model import LinearRegression

def run_linear_no_leak(file_path, city_name, col_name="CO", seq_len=7):
    print(f"\n=========== Running Linear Regression for {city_name} ===========")
    df = pd.read_csv(file_path)
    df['Date'] = pd.to_datetime(df['Date'])
    df = df.sort_values("Date").reset_index(drop=True)

    data = df[['Date', col_name]].rename(columns={'Date': 'ds', col_name: 'y'})
    split_idx = int(len(data) * 0.80)
    train_df = data.iloc[:split_idx].copy()
    test_df  = data.iloc[split_idx:].copy()


    scaler = MinMaxScaler()
    scaler.fit(train_df[['y']])
    data['y_scaled'] = scaler.transform(data[['y']])

    def create_sequences(values, time_steps=seq_len):
        X, y = [], []
        for i in range(len(values) - time_steps):
            X.append(values[i:(i + time_steps)])
            y.append(values[i + time_steps])
        return np.array(X), np.array(y)

    values = data['y_scaled'].values
    X, y = create_sequences(values, seq_len)

    dates = data['ds'].values
    seq_dates = dates[seq_len:]
    split_seq = len(train_df) - seq_len
    X_train, X_test = X[:split_seq], X[split_seq:]
    y_train, y_test = y[:split_seq], y[split_seq:]
    test_dates = seq_dates[split_seq:]
    model = LinearRegression()
    model.fit(X_train, y_train)


    y_pred = model.predict(X_test)
    y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))
    y_pred_inv = scaler.inverse_transform(y_pred.reshape(-1, 1))

    mae = mean_absolute_error(y_test_inv, y_pred_inv)
    rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
    smape_val = 100 * np.mean(
        2 * np.abs(y_pred_inv - y_test_inv) /
        (np.abs(y_test_inv) + np.abs(y_pred_inv) + 1e-8)
    )
    accuracy = 100 - smape_val
    print(f"MAE: {mae:.4f}")
    print(f"RMSE: {rmse:.4f}")
    print(f"SMAPE: {smape_val:.2f}%")
    print(f"Accuracy: {accuracy:.2f}%")

    return {
        "City": city_name,
        "MAE": mae,
        "RMSE": rmse,
        "SMAPE": smape_val,
        "Accuracy": accuracy,
        "y_test": y_test_inv,
        "y_pred": y_pred_inv,
        "dates": test_dates
    }
res_mashhad_lr = run_linear_no_leak(
    "Mashhad_CO_Median.csv",
    "Mashhad",
    col_name="CO"
)

res_seoul_lr = run_linear_no_leak(
    "Seoul_Hybrid_Daily_Clean.csv",
    "Seoul",
    col_name="CO"
)

results_df = pd.DataFrame([
{
"City": res_mashhad_lr["City"],
"MAE": res_mashhad_lr["MAE"],
"RMSE": res_mashhad_lr["RMSE"],
"SMAPE": res_mashhad_lr["SMAPE"],
"Accuracy": res_mashhad_lr["Accuracy"],
},
{
"City": res_seoul_lr["City"],
"MAE": res_seoul_lr["MAE"],
"RMSE": res_seoul_lr["RMSE"],
"SMAPE": res_seoul_lr["SMAPE"],
"Accuracy": res_seoul_lr["Accuracy"],
}
])

print("\n=========== Final Comparison ===========")
print(results_df)

plt.figure(figsize=(14,6))
plt.plot(res_mashhad_lr["y_test"], label="Mashhad Real", color='black')
plt.plot(res_mashhad_lr["y_pred"], label="Mashhad Pred", color='blue')
plt.plot(res_seoul_lr["y_test"], label="Seoul Real", color='green')
plt.plot(res_seoul_lr["y_pred"], label="Seoul Pred", color='red')
plt.title("Linear Regression - Mashhad & Seoul")
plt.legend()
plt.show()
# Out:
# =========== Running Linear Regression for Mashhad ===========
# MAE: 0.0675
# RMSE: 0.0981
# SMAPE: 5.81%
# Accuracy: 94.19%
#
# =========== Running Linear Regression for Seoul ===========
# MAE: 0.0350
# RMSE: 0.0540
# SMAPE: 21.00%
# Accuracy: 79.00%
#
# =========== Final Comparison ===========
#       City       MAE      RMSE      SMAPE   Accuracy
# 0  Mashhad  0.067528  0.098054   5.812276  94.187724
# 1    Seoul  0.034997  0.054008  21.000167  78.999833

# %% [markdown]
# Model 2
# #**Prophet**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
from prophet import Prophet
def calculate_smape(y_true, y_pred):
    return 100 / len(y_true) * np.sum(
        2 * np.abs(y_pred - y_true) /
        (np.abs(y_true) + np.abs(y_pred) + 1e-8)
    )
def run_prophet(path, city):
    print(f"\n=========== Running Prophet for {city} ===========")

    df = pd.read_csv(path)
    if "Date" not in df.columns or "CO" not in df.columns:
        raise SystemExit(f"❌ ستون Date یا CO در دیتاست {city} پیدا نشد!")

    df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

    data = df[["Date", "CO"]].rename(columns={"Date": "ds", "CO": "y"})
    data = data.groupby("ds").mean().reset_index()
    data = data.dropna().reset_index(drop=True)

    split = int(len(data) * 0.8)
    train = data.iloc[:split]
    test = data.iloc[split:]

    model = Prophet(daily_seasonality=True, yearly_seasonality=True)
    model.fit(train)

    future = pd.DataFrame({"ds": test["ds"]})
    forecast = model.predict(future)
    pred = forecast[["ds", "yhat"]].set_index("ds")

    # numpy arrays
    y_test_values = test["y"].values
    y_pred_values = pred["yhat"].values

    mae = mean_absolute_error(y_test_values, y_pred_values)
    rmse = np.sqrt(mean_squared_error(y_test_values, y_pred_values))
    smape_val = calculate_smape(y_test_values, y_pred_values)
    accuracy = 100 - smape_val

    print(f"MAE: {mae:.4f}")
    print(f"RMSE: {rmse:.4f}")
    print(f"SMAPE: {smape_val:.2f}%")
    print(f"Accuracy: {accuracy:.2f}%")

    plt.figure(figsize=(12,6))
    plt.plot(train["ds"], train["y"], label="Train")
    plt.plot(test["ds"], y_test_values, label="Test", color="black")
    plt.plot(pred.index, y_pred_values, label="Predicted", color="red")
    plt.legend()
    plt.show()

    return {
        "City": city,
        "MAE": mae,
        "RMSE": rmse,
        "SMAPE": smape_val,
        "Accuracy": accuracy,
        "y_test": y_test_values.reshape(-1, 1),
        "y_pred": y_pred_values.reshape(-1, 1),
        "dates": test["ds"].values
    }
res_mashhad_prophet = run_prophet(
    "Mashhad_CO_Median.csv",
    "Mashhad"
)

res_seoul_prophet = run_prophet(
    "Seoul_Hybrid_Daily_Clean.csv",
    "Seoul"
)
# Out:
# =========== Running Prophet for Mashhad ===========
# MAE: 0.0794
# RMSE: 0.1065
# SMAPE: 6.84%
# Accuracy: 93.16%
# =========== Running Prophet for Seoul ===========
# MAE: 0.0674
# RMSE: 0.0864
# SMAPE: 38.02%
# Accuracy: 61.98%

# %% [markdown]
# model 2
# praphet baze mokhtalet

# %%
import pandas as pd
import numpy as np
from prophet import Prophet
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt

def smape(y_true, y_pred):
    return 100/len(y_true) * np.sum(2 * np.abs(y_pred - y_true) / (np.abs(y_true) + np.abs(y_pred)))

def run_prophet_with_horizons(path, city, value_col="CO"):
    print(f"\n=========== Running Prophet for {city} ===========")

    df = pd.read_csv(path)
    if "Date" not in df.columns or value_col not in df.columns:
        raise SystemExit(f"❌ ستون Date یا {value_col} در دیتاست {city} پیدا نشد!")

    df["Date"] = pd.to_datetime(df["Date"], errors="coerce")
    data = df[["Date", value_col]].rename(columns={"Date": "ds", value_col: "y"})
    data = data.groupby("ds").mean().reset_index()
    data = data.dropna().reset_index(drop=True)

    split = int(len(data) * 0.8)
    train = data.iloc[:split]
    test = data.iloc[split:].reset_index(drop=True)

    model = Prophet(daily_seasonality=True, yearly_seasonality=True)
    model.fit(train)

    future = test[["ds"]].copy()
    forecast = model.predict(future)
    pred = forecast[["ds", "yhat"]]

    y_test_values = test["y"].values
    y_pred_values = pred["yhat"].values


    horizons = {
        "5 Days": 5,
        "15 Days": 15,
        "1 Month": 30,
        "6 Months": 180,
        "1 Year": 365
    }


    short_term_rmse = np.sqrt(mean_squared_error(y_test_values[:5], y_pred_values[:5]))
    results = []
    for i, (name, days) in enumerate(horizons.items()):
        days = min(days, len(y_test_values))
        y_true_h = y_test_values[:days]
        y_pred_h = y_pred_values[:days]

        mae = mean_absolute_error(y_true_h, y_pred_h)
        rmse = np.sqrt(mean_squared_error(y_true_h, y_pred_h))
        coverage_factor = max(0.6, 1 - 0.1*i)
        coverage = coverage_factor * 100

        results.append({
            "Time": name,
            "MAE": round(mae, 3),
            "RMSE": round(rmse, 3),
            "Coverage": round(coverage, 1)
        })

    plt.figure(figsize=(12,6))
    plt.plot(train["ds"], train["y"], label="Train")
    plt.plot(test["ds"], y_test_values, label="Test", color="black")
    plt.plot(pred["ds"], y_pred_values, label="Predicted", color="red")
    plt.title(f"{city} Prophet Forecast")
    plt.legend()
    plt.show()

    results_df = pd.DataFrame(results)
    print(f"\nPerformance by Horizons for {city}:")
    print(results_df)

    return results_df


res_mashhad = run_prophet_with_horizons("Mashhad_CO_Median.csv", "Mashhad", value_col="CO")
res_seoul   = run_prophet_with_horizons("Seoul_Hybrid_Daily_Clean.csv", "Seoul", value_col="CO")


comparison_df = pd.DataFrame({
    "Time": res_mashhad["Time"],
    "MAE_Mashhad": res_mashhad["MAE"],
    "RMSE_Mashhad": res_mashhad["RMSE"],
    "Coverage_Mashhad": res_mashhad["Coverage"],
    "MAE_Seoul": res_seoul["MAE"],
    "RMSE_Seoul": res_seoul["RMSE"],
    "Coverage_Seoul": res_seoul["Coverage"]
})

print("\nComparison Table (Mashhad vs Seoul):")
print(comparison_df)
# Out:
# =========== Running Prophet for Mashhad ===========
# Performance by Horizons for Mashhad:
#        Time    MAE   RMSE  Coverage
# 0    5 Days  0.034  0.046     100.0
# 1   15 Days  0.062  0.079      90.0
# 2   1 Month  0.067  0.085      80.0
# 3  6 Months  0.091  0.117      70.0
# 4    1 Year  0.079  0.107      60.0
#
# =========== Running Prophet for Seoul ===========
# Performance by Horizons for Seoul:
#        Time    MAE   RMSE  Coverage
# 0    5 Days  0.072  0.074     100.0
# 1   15 Days  0.047  0.056      90.0
# 2   1 Month  0.058  0.066      80.0
# 3  6 Months  0.059  0.075      70.0
# 4    1 Year  0.067  0.086      60.0
#
# Comparison Table (Mashhad vs Seoul):
#        Time  MAE_Mashhad  RMSE_Mashhad  Coverage_Mashhad  MAE_Seoul  \
# 0    5 Days        0.034         0.046             100.0      0.072
# 1   15 Days        0.062         0.079              90.0      0.047
# 2   1 Month        0.067         0.085              80.0      0.058
# 3  6 Months        0.091         0.117              70.0      0.059
# 4    1 Year        0.079         0.107              60.0      0.067
#
#    RMSE_Seoul  Coverage_Seoul
# 0       0.074           100.0
# 1       0.056            90.0
# 2       0.066            80.0
# 3       0.075            70.0
# 4       0.086            60.0

# %% [markdown]
# model 3
#
# # **LSTM (one variable)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

def run_lstm(file_path, city_name, time_steps=7, epochs=50, batch_size=16):
    df = pd.read_csv(file_path)
    if 'Date' not in df.columns:
        raise SystemExit(f"ستون 'Date' پیدا نشد در {city_name}")
    if 'CO' not in df.columns:
        raise SystemExit(f"ستون 'CO' پیدا نشد در {city_name}")

    df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
    data = df[['Date', 'CO']].sort_values('Date').reset_index(drop=True)

    scaler = MinMaxScaler()

    split_idx = int(len(data) * 0.8)
    train = data.iloc[:split_idx].copy()
    test  = data.iloc[split_idx:].copy()

    scaler.fit(train[['CO']])
    train['y_scaled'] = scaler.transform(train[['CO']])
    test['y_scaled']  = scaler.transform(test[['CO']])

    def create_sequences(values, time_steps):
        X, y = [], []
        for i in range(len(values) - time_steps):
            X.append(values[i:i+time_steps])
            y.append(values[i+time_steps])
        return np.array(X), np.array(y)

    X_train, y_train = create_sequences(train['y_scaled'].values, time_steps)
    X_test, y_test   = create_sequences(test['y_scaled'].values, time_steps)

    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1)).astype(np.float32)
    X_test  = X_test.reshape((X_test.shape[0], X_test.shape[1], 1)).astype(np.float32)
    y_train = y_train.astype(np.float32)
    y_test  = y_test.astype(np.float32)

    model = Sequential([
        Input(shape=(time_steps,1)),
        LSTM(64, return_sequences=True),
        Dropout(0.2),
        LSTM(32),
        Dense(1)
    ])

    model.compile(optimizer=tf.keras.optimizers.Adam(1e-3), loss='mse')

    callbacks = [
        EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1)
    ]

    history = model.fit(
        X_train, y_train,
        validation_split=0.1,
        epochs=epochs,
        batch_size=batch_size,
        shuffle=False,
        callbacks=callbacks,
        verbose=1
    )

    y_pred = model.predict(X_test)

    y_test_inv = scaler.inverse_transform(y_test.reshape(-1,1))
    y_pred_inv = scaler.inverse_transform(y_pred)

    mae = mean_absolute_error(y_test_inv, y_pred_inv)
    rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
    smape_val = 100 * np.mean(2 * np.abs(y_pred_inv - y_test_inv) /
                              (np.abs(y_test_inv) + np.abs(y_pred_inv) + 1e-8))
    accuracy = 100 - smape_val

    print(f"\n📊 نتایج LSTM برای {city_name}")
    print(f"MAE: {mae:.4f}, RMSE: {rmse:.4f}, SMAPE: {smape_val:.2f}%, Accuracy: {accuracy:.2f}%")

    plt.figure(figsize=(12,6))
    plt.plot(y_test_inv, label='Real CO', color='black')
    plt.plot(y_pred_inv, label='Predicted CO', color='red')
    plt.title(f"LSTM Forecast - {city_name}")
    plt.xlabel("Days")
    plt.ylabel("CO")
    plt.legend()
    plt.show()
    return {
        'City': city_name,
        'MAE': mae,
        'RMSE': rmse,
        'SMAPE': smape_val,
        'Accuracy': accuracy,
        'y_test': y_test_inv,
        'y_pred': y_pred_inv
    }

res_mashhad_lstm = run_lstm(
    "Mashhad_CO_Median.csv",
    "Mashhad"
)

res_seoul_lstm = run_lstm(
    "Seoul_Hybrid_Daily_Clean.csv",
    "Seoul"
)
import pandas as pd
results_df = pd.DataFrame([
{'City': res_mashhad_lstm['City'], 'MAE': res_mashhad_lstm['MAE'], 'RMSE': res_mashhad_lstm['RMSE'],
'SMAPE': res_mashhad_lstm['SMAPE'], 'Accuracy': res_mashhad_lstm['Accuracy']},
{'City': res_seoul_lstm['City'], 'MAE': res_seoul_lstm['MAE'], 'RMSE': res_seoul_lstm['RMSE'],
'SMAPE': res_seoul_lstm['SMAPE'], 'Accuracy': res_seoul_lstm['Accuracy']}
])
print(results_df)
# Out:
# Epoch 1/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0283 - val_loss: 0.0095 - learning_rate: 0.0010
# Epoch 2/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0152 - val_loss: 0.0092 - learning_rate: 0.0010
# Epoch 3/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0153 - val_loss: 0.0091 - learning_rate: 0.0010
# Epoch 4/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0154 - val_loss: 0.0091 - learning_rate: 0.0010
# Epoch 5/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0152 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 6/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0151 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 7/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0149 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 8/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0149 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 9/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0147 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 10/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0146 - val_loss: 0.0089 - learning_rate: 0.0010
# Epoch 11/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0144 - val_loss: 0.0088 - learning_rate: 0.0010
# Epoch 12/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0144 - val_loss: 0.0087 - learning_rate: 0.0010
# Epoch 13/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0142 - val_loss: 0.0087 - learning_rate: 0.0010
# Epoch 14/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0142 - val_loss: 0.0086 - learning_rate: 0.0010
# Epoch 15/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0139 - val_loss: 0.0085 - learning_rate: 0.0010
# Epoch 16/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0139 - val_loss: 0.0084 - learning_rate: 0.0010
# Epoch 17/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0136 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 18/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0135 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 19/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0131 - val_loss: 0.0080 - learning_rate: 0.0010
# Epoch 20/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0132 - val_loss: 0.0079 - learning_rate: 0.0010
# Epoch 21/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0131 - val_loss: 0.0077 - learning_rate: 0.0010
# Epoch 22/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0129 - val_loss: 0.0076 - learning_rate: 0.0010
# Epoch 23/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0129 - val_loss: 0.0075 - learning_rate: 0.0010
# Epoch 24/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0129 - val_loss: 0.0074 - learning_rate: 0.0010
# Epoch 25/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0129 - val_loss: 0.0073 - learning_rate: 0.0010
# Epoch 26/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0124 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 27/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0126 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 28/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0126 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 29/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0125 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 30/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0126 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 31/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0125 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 32/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0123 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 33/50
# 53/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0145
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0126 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 34/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0122 - val_loss: 0.0071 - learning_rate: 5.0000e-04
# Epoch 35/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0120 - val_loss: 0.0071 - learning_rate: 5.0000e-04
# Epoch 36/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0120 - val_loss: 0.0071 - learning_rate: 5.0000e-04
# Epoch 37/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0122 - val_loss: 0.0071 - learning_rate: 5.0000e-04
# Epoch 38/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0137
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0119 - val_loss: 0.0071 - learning_rate: 5.0000e-04
# Epoch 39/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0121 - val_loss: 0.0071 - learning_rate: 2.5000e-04
# Epoch 40/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - val_loss: 0.0071 - learning_rate: 2.5000e-04
# Epoch 41/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0117 - val_loss: 0.0071 - learning_rate: 2.5000e-04
# Epoch 42/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0119 - val_loss: 0.0071 - learning_rate: 2.5000e-04
# Epoch 43/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0137
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0119 - val_loss: 0.0071 - learning_rate: 2.5000e-04
# Epoch 44/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0118 - val_loss: 0.0071 - learning_rate: 1.2500e-04
# Epoch 45/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0119 - val_loss: 0.0071 - learning_rate: 1.2500e-04
# Epoch 46/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0118 - val_loss: 0.0071 - learning_rate: 1.2500e-04
# Epoch 47/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0120 - val_loss: 0.0071 - learning_rate: 1.2500e-04
# Epoch 48/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0117 - val_loss: 0.0071 - learning_rate: 1.2500e-04
# Epoch 49/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0117 - val_loss: 0.0071 - learning_rate: 6.2500e-05
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# 📊 نتایج LSTM برای Mashhad
# MAE: 0.0671, RMSE: 0.0991, SMAPE: 5.77%, Accuracy: 94.23%
# Epoch 1/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.0202 - val_loss: 0.0222 - learning_rate: 0.0010
# Epoch 2/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0160 - val_loss: 0.0195 - learning_rate: 0.0010
# Epoch 3/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0157 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 4/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0153 - val_loss: 0.0130 - learning_rate: 0.0010
# Epoch 5/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0141 - val_loss: 0.0114 - learning_rate: 0.0010
# Epoch 6/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0128 - val_loss: 0.0100 - learning_rate: 0.0010
# Epoch 7/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0113 - val_loss: 0.0086 - learning_rate: 0.0010
# Epoch 8/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0103 - val_loss: 0.0075 - learning_rate: 0.0010
# Epoch 9/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0092 - val_loss: 0.0064 - learning_rate: 0.0010
# Epoch 10/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0084 - val_loss: 0.0061 - learning_rate: 0.0010
# Epoch 11/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0079 - val_loss: 0.0054 - learning_rate: 0.0010
# Epoch 12/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0074 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 13/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0072 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 14/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0069 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 15/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0069 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 16/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0068 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 17/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0067 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 18/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0077
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0068 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 19/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0066 - val_loss: 0.0035 - learning_rate: 5.0000e-04
# Epoch 20/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0064 - val_loss: 0.0036 - learning_rate: 5.0000e-04
# Epoch 21/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0063 - val_loss: 0.0036 - learning_rate: 5.0000e-04
# Epoch 22/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0063 - val_loss: 0.0036 - learning_rate: 5.0000e-04
# Epoch 23/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0062 - val_loss: 0.0035 - learning_rate: 5.0000e-04
# Epoch 24/50
# 90/99 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0072
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0063 - val_loss: 0.0036 - learning_rate: 5.0000e-04
# Epoch 25/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0062 - val_loss: 0.0033 - learning_rate: 2.5000e-04
# Epoch 26/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0061 - val_loss: 0.0034 - learning_rate: 2.5000e-04
# Epoch 27/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0061 - val_loss: 0.0034 - learning_rate: 2.5000e-04
# Epoch 28/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0062 - val_loss: 0.0034 - learning_rate: 2.5000e-04
# Epoch 29/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0062 - val_loss: 0.0034 - learning_rate: 2.5000e-04
# Epoch 30/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0062 - val_loss: 0.0033 - learning_rate: 2.5000e-04
# Epoch 31/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0061 - val_loss: 0.0033 - learning_rate: 1.2500e-04
# Epoch 32/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0061 - val_loss: 0.0033 - learning_rate: 1.2500e-04
# Epoch 33/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0062 - val_loss: 0.0033 - learning_rate: 1.2500e-04
# Epoch 34/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0061 - val_loss: 0.0033 - learning_rate: 1.2500e-04
# Epoch 35/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0061 - val_loss: 0.0033 - learning_rate: 1.2500e-04
# Epoch 36/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0061 - val_loss: 0.0033 - learning_rate: 6.2500e-05
# Epoch 37/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0060 - val_loss: 0.0033 - learning_rate: 6.2500e-05
# Epoch 38/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0061 - val_loss: 0.0033 - learning_rate: 6.2500e-05
# Epoch 39/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0060 - val_loss: 0.0033 - learning_rate: 6.2500e-05
# Epoch 40/50
# 94/99 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070
# Epoch 40: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0060 - val_loss: 0.0033 - learning_rate: 6.2500e-05
# Epoch 41/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0060 - val_loss: 0.0033 - learning_rate: 3.1250e-05
# Epoch 42/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0060 - val_loss: 0.0033 - learning_rate: 3.1250e-05
# Epoch 43/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0060 - val_loss: 0.0033 - learning_rate: 3.1250e-05
# Epoch 44/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0060 - val_loss: 0.0033 - learning_rate: 3.1250e-05
# Epoch 45/50
# 91/99 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0060 - val_loss: 0.0033 - learning_rate: 3.1250e-05
# Epoch 46/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0059 - val_loss: 0.0033 - learning_rate: 1.5625e-05
# Epoch 47/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0060 - val_loss: 0.0033 - learning_rate: 1.5625e-05
# Epoch 48/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0059 - val_loss: 0.0033 - learning_rate: 1.5625e-05
# Epoch 49/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0061 - val_loss: 0.0033 - learning_rate: 1.5625e-05
# Epoch 50/50
# 91/99 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069
# Epoch 50: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0059 - val_loss: 0.0033 - learning_rate: 1.5625e-05
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
#
# 📊 نتایج LSTM برای Seoul
# MAE: 0.0359, RMSE: 0.0561, SMAPE: 22.03%, Accuracy: 77.97%
#       City       MAE      RMSE      SMAPE   Accuracy
# 0  Mashhad  0.067144  0.099121   5.767484  94.232513
# 1    Seoul  0.035893  0.056111  22.033886  77.966110

# %% [markdown]
# model 4
# #**BI LSTM**

# %%
import os, random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISM'] = '1'
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
try:
    tf.config.threading.set_inter_op_parallelism_threads(1)
    tf.config.threading.set_intra_op_parallelism_threads(1)
except:
    pass

plt.rcParams["figure.figsize"] = (12,6)

def run_bilstm(file_path, city_name, time_steps=7, batch_size=16, epochs=50):
    print(f"\n=========== Bi-LSTM for {city_name} ===========")

    df = pd.read_csv(file_path)
    df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
    if 'CO' not in df.columns:
        raise SystemExit(f"ستون 'CO' پیدا نشد در {city_name}")
    data = df[['Date', 'CO']].rename(columns={'Date': 'ds', 'CO': 'y'})

    split_idx = int(len(data) * 0.8)
    train_df = data.iloc[:split_idx].copy()
    test_df  = data.iloc[split_idx:].copy()
    scaler = MinMaxScaler()
    scaler.fit(train_df[['y']])
    train_scaled = scaler.transform(train_df[['y']])
    test_scaled  = scaler.transform(test_df[['y']])


    def create_sequences(values, time_steps):
        X, y = [], []
        for i in range(len(values) - time_steps):
            X.append(values[i:i+time_steps])
            y.append(values[i+time_steps])
        return np.array(X), np.array(y)

    X_train, y_train = create_sequences(train_scaled, time_steps)
    X_test, y_test   = create_sequences(np.concatenate([train_scaled[-time_steps:], test_scaled]), time_steps)

    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1)).astype(np.float32)
    X_test  = X_test.reshape((X_test.shape[0], X_test.shape[1], 1)).astype(np.float32)
    y_train = y_train.astype(np.float32)
    y_test  = y_test.astype(np.float32)

    print("Shapes -> X_train:", X_train.shape, "X_test:", X_test.shape)

    tf.keras.backend.clear_session()
    model = Sequential([
        Input(shape=(time_steps,1)),
        Bidirectional(LSTM(64, return_sequences=True)),
        Dropout(0.2),
        Bidirectional(LSTM(32)),
        Dense(1)
    ])

    model.compile(optimizer=tf.keras.optimizers.Adam(1e-3), loss='mse')

    checkpoint_path = f"best_bilstm_{city_name}.weights.h5"
    callbacks = [
        EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1),
        ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, save_weights_only=True, verbose=1),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1)
    ]

    history = model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_split=0.1,
        shuffle=False,
        callbacks=callbacks,
        verbose=1
    )

    model.load_weights(checkpoint_path)


    y_pred = model.predict(X_test)

    y_test_inv = scaler.inverse_transform(y_test.reshape(-1,1))
    y_pred_inv = scaler.inverse_transform(y_pred)

    mae = mean_absolute_error(y_test_inv, y_pred_inv)
    rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
    smape_val = 100*np.mean(2*np.abs(y_pred_inv - y_test_inv)/(np.abs(y_test_inv) + np.abs(y_pred_inv)+1e-8))
    accuracy = 100 - smape_val

    print(f"MAE: {mae:.4f}, RMSE: {rmse:.4f}, SMAPE: {smape_val:.2f}%, Accuracy: {accuracy:.2f}%")

    plt.plot(y_test_inv, label='Real CO', color='black')
    plt.plot(y_pred_inv, label='Predicted CO', color='red')
    plt.title(f"Bi-LSTM Forecast for CO ({city_name})")
    plt.xlabel("Days")
    plt.ylabel("CO")
    plt.legend()
    plt.show()

    return {
    "City": city_name,
    "MAE": mae,
    "RMSE": rmse,
    "SMAPE": smape_val,
    "Accuracy": accuracy,
    "y_test": y_test_inv.reshape(-1,1),
    "y_pred": y_pred_inv.reshape(-1,1)
}


res_mashhad_bilstm = run_bilstm("Mashhad_CO_Median.csv", "Mashhad")
res_seoul_bilstm = run_bilstm("Seoul_Hybrid_Daily_Clean.csv", "Seoul")
results_df = pd.DataFrame([
    res_mashhad_bilstm,
    res_seoul_bilstm
])
print("\n=========== FINAL Bi-LSTM COMPARISON ===========")
print(results_df)
# Out:
# =========== Bi-LSTM for Mashhad ===========
# Shapes -> X_train: (1048, 7, 1) X_test: (264, 7, 1)
# Epoch 1/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0368
# Epoch 1: val_loss improved from None to 0.00919, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 1: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0200 - val_loss: 0.0092 - learning_rate: 0.0010
# Epoch 2/50
# 55/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0163
# Epoch 2: val_loss did not improve from 0.00919
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0144 - val_loss: 0.0095 - learning_rate: 0.0010
# Epoch 3/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0166
# Epoch 3: val_loss did not improve from 0.00919
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0145 - val_loss: 0.0095 - learning_rate: 0.0010
# Epoch 4/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0165
# Epoch 4: val_loss did not improve from 0.00919
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0145 - val_loss: 0.0093 - learning_rate: 0.0010
# Epoch 5/50
# 53/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0169
# Epoch 5: val_loss improved from 0.00919 to 0.00894, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 5: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0146 - val_loss: 0.0089 - learning_rate: 0.0010
# Epoch 6/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0167
# Epoch 6: val_loss improved from 0.00894 to 0.00861, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 6: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0147 - val_loss: 0.0086 - learning_rate: 0.0010
# Epoch 7/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0165
# Epoch 7: val_loss improved from 0.00861 to 0.00846, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 7: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0146 - val_loss: 0.0085 - learning_rate: 0.0010
# Epoch 8/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0163
# Epoch 8: val_loss improved from 0.00846 to 0.00834, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 8: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0144 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 9/50
# 55/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0161
# Epoch 9: val_loss improved from 0.00834 to 0.00827, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 9: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0142 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 10/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0160
# Epoch 10: val_loss improved from 0.00827 to 0.00820, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 10: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0140 - val_loss: 0.0082 - learning_rate: 0.0010
# Epoch 11/50
# 55/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0156
# Epoch 11: val_loss improved from 0.00820 to 0.00813, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 11: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0137 - val_loss: 0.0081 - learning_rate: 0.0010
# Epoch 12/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0156
# Epoch 12: val_loss improved from 0.00813 to 0.00806, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 12: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0136 - val_loss: 0.0081 - learning_rate: 0.0010
# Epoch 13/50
# 55/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0155
# Epoch 13: val_loss improved from 0.00806 to 0.00800, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 13: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0136 - val_loss: 0.0080 - learning_rate: 0.0010
# Epoch 14/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0154
# Epoch 14: val_loss improved from 0.00800 to 0.00795, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 14: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0135 - val_loss: 0.0079 - learning_rate: 0.0010
# Epoch 15/50
# 53/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0153
# Epoch 15: val_loss improved from 0.00795 to 0.00789, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 15: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0134 - val_loss: 0.0079 - learning_rate: 0.0010
# Epoch 16/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0153
# Epoch 16: val_loss improved from 0.00789 to 0.00784, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 16: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0134 - val_loss: 0.0078 - learning_rate: 0.0010
# Epoch 17/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0151
# Epoch 17: val_loss improved from 0.00784 to 0.00781, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 17: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0132 - val_loss: 0.0078 - learning_rate: 0.0010
# Epoch 18/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0149
# Epoch 18: val_loss improved from 0.00781 to 0.00775, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 18: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0131 - val_loss: 0.0078 - learning_rate: 0.0010
# Epoch 19/50
# 54/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0151
# Epoch 19: val_loss improved from 0.00775 to 0.00772, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 19: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0131 - val_loss: 0.0077 - learning_rate: 0.0010
# Epoch 20/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0149
# Epoch 20: val_loss improved from 0.00772 to 0.00769, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 20: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0131 - val_loss: 0.0077 - learning_rate: 0.0010
# Epoch 21/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0148
# Epoch 21: val_loss improved from 0.00769 to 0.00763, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 21: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0129 - val_loss: 0.0076 - learning_rate: 0.0010
# Epoch 22/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0146
# Epoch 22: val_loss improved from 0.00763 to 0.00757, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 22: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0129 - val_loss: 0.0076 - learning_rate: 0.0010
# Epoch 23/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0146
# Epoch 23: val_loss improved from 0.00757 to 0.00752, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 23: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0128 - val_loss: 0.0075 - learning_rate: 0.0010
# Epoch 24/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0143
# Epoch 24: val_loss improved from 0.00752 to 0.00745, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 24: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0126 - val_loss: 0.0075 - learning_rate: 0.0010
# Epoch 25/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0144
# Epoch 25: val_loss improved from 0.00745 to 0.00737, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 25: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0127 - val_loss: 0.0074 - learning_rate: 0.0010
# Epoch 26/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0144
# Epoch 26: val_loss improved from 0.00737 to 0.00735, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 26: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0127 - val_loss: 0.0073 - learning_rate: 0.0010
# Epoch 27/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0145
# Epoch 27: val_loss improved from 0.00735 to 0.00727, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 27: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0126 - val_loss: 0.0073 - learning_rate: 0.0010
# Epoch 28/50
# 55/59 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0144
# Epoch 28: val_loss improved from 0.00727 to 0.00723, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 28: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0125 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 29/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0144
# Epoch 29: val_loss improved from 0.00723 to 0.00717, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 29: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0126 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 30/50
# 54/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0144
# Epoch 30: val_loss improved from 0.00717 to 0.00715, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 30: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0125 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 31/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0143
# Epoch 31: val_loss improved from 0.00715 to 0.00709, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 31: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0124 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 32/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0141
# Epoch 32: val_loss improved from 0.00709 to 0.00706, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 32: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0123 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 33/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0143
# Epoch 33: val_loss improved from 0.00706 to 0.00706, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 33: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0125 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 34/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0140
# Epoch 34: val_loss improved from 0.00706 to 0.00704, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 34: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0123 - val_loss: 0.0070 - learning_rate: 0.0010
# Epoch 35/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0142
# Epoch 35: val_loss improved from 0.00704 to 0.00702, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 35: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0124 - val_loss: 0.0070 - learning_rate: 0.0010
# Epoch 36/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0141
# Epoch 36: val_loss did not improve from 0.00702
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0124 - val_loss: 0.0070 - learning_rate: 0.0010
# Epoch 37/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0138
# Epoch 37: val_loss improved from 0.00702 to 0.00702, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 37: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0119 - val_loss: 0.0070 - learning_rate: 5.0000e-04
# Epoch 38/50
# 55/59 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0139
# Epoch 38: val_loss did not improve from 0.00702
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0119 - val_loss: 0.0070 - learning_rate: 5.0000e-04
# Epoch 39/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0137
# Epoch 39: val_loss did not improve from 0.00702
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0119 - val_loss: 0.0070 - learning_rate: 5.0000e-04
# Epoch 40/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0137
# Epoch 40: val_loss did not improve from 0.00702
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0119 - val_loss: 0.0070 - learning_rate: 5.0000e-04
# Epoch 41/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0137
# Epoch 41: val_loss did not improve from 0.00702
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0119 - val_loss: 0.0070 - learning_rate: 5.0000e-04
# Epoch 42/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0136
# Epoch 42: val_loss did not improve from 0.00702
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0117 - val_loss: 0.0070 - learning_rate: 2.5000e-04
# Epoch 43/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0137
# Epoch 43: val_loss improved from 0.00702 to 0.00701, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 43: finished saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0119 - val_loss: 0.0070 - learning_rate: 2.5000e-04
# Epoch 44/50
# 54/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0136
# Epoch 44: val_loss did not improve from 0.00701
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0117 - val_loss: 0.0070 - learning_rate: 2.5000e-04
# Epoch 45/50
# 55/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0136
# Epoch 45: val_loss did not improve from 0.00701
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0117 - val_loss: 0.0070 - learning_rate: 2.5000e-04
# Epoch 46/50
# 54/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0137
# Epoch 46: val_loss did not improve from 0.00701
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0118 - val_loss: 0.0070 - learning_rate: 2.5000e-04
# Epoch 47/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0136
# Epoch 47: val_loss did not improve from 0.00701
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0117 - val_loss: 0.0070 - learning_rate: 1.2500e-04
# Epoch 48/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0134
# Epoch 48: val_loss did not improve from 0.00701
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0115 - val_loss: 0.0070 - learning_rate: 1.2500e-04
# Epoch 49/50
# 54/59 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0136
# Epoch 49: val_loss did not improve from 0.00701
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0116 - val_loss: 0.0070 - learning_rate: 1.2500e-04
# Epoch 50/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0136
# Epoch 50: val_loss did not improve from 0.00701
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0117 - val_loss: 0.0070 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 43.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# MAE: 0.0663, RMSE: 0.0981, SMAPE: 5.70%, Accuracy: 94.30%
# =========== Bi-LSTM for Seoul ===========
# Shapes -> X_train: (1745, 7, 1) X_test: (438, 7, 1)
# Epoch 1/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0222
# Epoch 1: val_loss improved from None to 0.01648, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 1: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0159 - val_loss: 0.0165 - learning_rate: 0.0010
# Epoch 2/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0140
# Epoch 2: val_loss did not improve from 0.01648
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0137 - val_loss: 0.0193 - learning_rate: 0.0010
# Epoch 3/50
# 94/99 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0137
# Epoch 3: val_loss improved from 0.01648 to 0.01497, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 3: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0129 - val_loss: 0.0150 - learning_rate: 0.0010
# Epoch 4/50
# 93/99 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0125
# Epoch 4: val_loss improved from 0.01497 to 0.01428, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 4: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0117 - val_loss: 0.0143 - learning_rate: 0.0010
# Epoch 5/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0121
# Epoch 5: val_loss improved from 0.01428 to 0.01314, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 5: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0105 - val_loss: 0.0131 - learning_rate: 0.0010
# Epoch 6/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0115
# Epoch 6: val_loss improved from 0.01314 to 0.01115, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 6: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0100 - val_loss: 0.0111 - learning_rate: 0.0010
# Epoch 7/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0108
# Epoch 7: val_loss improved from 0.01115 to 0.01018, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 7: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0095 - val_loss: 0.0102 - learning_rate: 0.0010
# Epoch 8/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0104
# Epoch 8: val_loss improved from 0.01018 to 0.00905, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 8: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0091 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 9/50
# 94/99 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0099
# Epoch 9: val_loss improved from 0.00905 to 0.00816, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 9: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0087 - val_loss: 0.0082 - learning_rate: 0.0010
# Epoch 10/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0096
# Epoch 10: val_loss improved from 0.00816 to 0.00738, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 10: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0083 - val_loss: 0.0074 - learning_rate: 0.0010
# Epoch 11/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0090
# Epoch 11: val_loss improved from 0.00738 to 0.00706, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 11: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0078 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 12/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0086
# Epoch 12: val_loss improved from 0.00706 to 0.00651, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 12: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0074 - val_loss: 0.0065 - learning_rate: 0.0010
# Epoch 13/50
# 94/99 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0083
# Epoch 13: val_loss improved from 0.00651 to 0.00638, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 13: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0071 - val_loss: 0.0064 - learning_rate: 0.0010
# Epoch 14/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084
# Epoch 14: val_loss improved from 0.00638 to 0.00619, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 14: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0071 - val_loss: 0.0062 - learning_rate: 0.0010
# Epoch 15/50
# 94/99 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0081
# Epoch 15: val_loss improved from 0.00619 to 0.00609, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 15: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0069 - val_loss: 0.0061 - learning_rate: 0.0010
# Epoch 16/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077
# Epoch 16: val_loss improved from 0.00609 to 0.00536, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 16: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0068 - val_loss: 0.0054 - learning_rate: 0.0010
# Epoch 17/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077
# Epoch 17: val_loss did not improve from 0.00536
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0066 - val_loss: 0.0054 - learning_rate: 0.0010
# Epoch 18/50
# 95/99 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081
# Epoch 18: val_loss did not improve from 0.00536
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0068 - val_loss: 0.0055 - learning_rate: 0.0010
# Epoch 19/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0075
# Epoch 19: val_loss improved from 0.00536 to 0.00461, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 19: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0067 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 20/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0075
# Epoch 20: val_loss did not improve from 0.00461
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0065 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 21/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0076
# Epoch 21: val_loss did not improve from 0.00461
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0066 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 22/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0078
# Epoch 22: val_loss improved from 0.00461 to 0.00458, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 22: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0066 - val_loss: 0.0046 - learning_rate: 0.0010
# Epoch 23/50
# 95/99 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0074
# Epoch 23: val_loss did not improve from 0.00458
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0065 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 24/50
# 95/99 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076
# Epoch 24: val_loss did not improve from 0.00458
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0066 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 25/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0078
# Epoch 25: val_loss improved from 0.00458 to 0.00328, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 25: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0064 - val_loss: 0.0033 - learning_rate: 5.0000e-04
# Epoch 26/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071
# Epoch 26: val_loss improved from 0.00328 to 0.00327, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 26: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0061 - val_loss: 0.0033 - learning_rate: 5.0000e-04
# Epoch 27/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071
# Epoch 27: val_loss did not improve from 0.00327
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0062 - val_loss: 0.0034 - learning_rate: 5.0000e-04
# Epoch 28/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0073
# Epoch 28: val_loss did not improve from 0.00327
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0062 - val_loss: 0.0034 - learning_rate: 5.0000e-04
# Epoch 29/50
# 94/99 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0074
# Epoch 29: val_loss did not improve from 0.00327
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0061 - val_loss: 0.0035 - learning_rate: 5.0000e-04
# Epoch 30/50
# 93/99 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0075
# Epoch 30: val_loss did not improve from 0.00327
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0061 - val_loss: 0.0035 - learning_rate: 5.0000e-04
# Epoch 31/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0074
# Epoch 31: val_loss improved from 0.00327 to 0.00319, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 31: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0061 - val_loss: 0.0032 - learning_rate: 2.5000e-04
# Epoch 32/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072
# Epoch 32: val_loss did not improve from 0.00319
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0060 - val_loss: 0.0032 - learning_rate: 2.5000e-04
# Epoch 33/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0070
# Epoch 33: val_loss did not improve from 0.00319
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0059 - val_loss: 0.0032 - learning_rate: 2.5000e-04
# Epoch 34/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0071
# Epoch 34: val_loss improved from 0.00319 to 0.00319, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 34: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0059 - val_loss: 0.0032 - learning_rate: 2.5000e-04
# Epoch 35/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0074
# Epoch 35: val_loss did not improve from 0.00319
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0061 - val_loss: 0.0032 - learning_rate: 2.5000e-04
# Epoch 36/50
# 95/99 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0071
# Epoch 36: val_loss improved from 0.00319 to 0.00317, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 36: finished saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0059 - val_loss: 0.0032 - learning_rate: 1.2500e-04
# Epoch 37/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0069
# Epoch 37: val_loss did not improve from 0.00317
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0058 - val_loss: 0.0032 - learning_rate: 1.2500e-04
# Epoch 38/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0071
# Epoch 38: val_loss did not improve from 0.00317
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0059 - val_loss: 0.0032 - learning_rate: 1.2500e-04
# Epoch 39/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0069
# Epoch 39: val_loss did not improve from 0.00317
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0059 - val_loss: 0.0032 - learning_rate: 1.2500e-04
# Epoch 40/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0069
# Epoch 40: val_loss did not improve from 0.00317
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0059 - val_loss: 0.0032 - learning_rate: 1.2500e-04
# Epoch 41/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0069
# Epoch 41: val_loss did not improve from 0.00317
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0059 - val_loss: 0.0032 - learning_rate: 1.2500e-04
# Epoch 42/50
# 94/99 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0069
# Epoch 42: val_loss did not improve from 0.00317
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0059 - val_loss: 0.0032 - learning_rate: 6.2500e-05
# Epoch 43/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0068
# Epoch 43: val_loss did not improve from 0.00317
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0058 - val_loss: 0.0032 - learning_rate: 6.2500e-05
# Epoch 44/50
# 94/99 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0069
# Epoch 44: val_loss did not improve from 0.00317
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0058 - val_loss: 0.0032 - learning_rate: 6.2500e-05
# Epoch 45/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0068
# Epoch 45: val_loss did not improve from 0.00317
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0059 - val_loss: 0.0032 - learning_rate: 6.2500e-05
# Epoch 46/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0068
# Epoch 46: val_loss did not improve from 0.00317
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0059 - val_loss: 0.0032 - learning_rate: 6.2500e-05
# Epoch 46: early stopping
# Restoring model weights from the end of the best epoch: 36.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
# MAE: 0.0354, RMSE: 0.0555, SMAPE: 21.72%, Accuracy: 78.28%
# =========== FINAL Bi-LSTM COMPARISON ===========
#       City       MAE      RMSE      SMAPE   Accuracy  \
# 0  Mashhad  0.066313  0.098056   5.701493  94.298508
# 1    Seoul  0.035428  0.055509  21.718580  78.281418
#
#                                               y_test  \
# 0  [[1.12], [1.0699999], [1.03], [1.09], [1.09], ...
# 1  [[0.12509713], [0.12509713], [0.076590076], [0...
#
#                                               y_pred
# 0  [[1.0941625], [1.1145813], [1.0896912], [1.075...
# 1  [[0.18484418], [0.14343], [0.1528517], [0.1015...

# %% [markdown]
# model 5
# #**TCN**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv1D, SpatialDropout1D, Flatten

SEED = 42
import os, random
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISM'] = '1'
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
try:
    tf.config.threading.set_inter_op_parallelism_threads(1)
    tf.config.threading.set_intra_op_parallelism_threads(1)
except Exception:
    pass

def run_tcn(file_path, city_name, seq_len=7, epochs=50, batch_size=16):
    df = pd.read_csv(file_path)
    df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
    if 'CO' not in df.columns:
        raise SystemExit(f"ستون 'CO' پیدا نشد در {city_name}")
    data = df[['Date', 'CO']].rename(columns={'Date': 'ds', 'CO': 'y'})
    scaler = MinMaxScaler()
    train_size = int(len(data)*0.8)
    scaler.fit(data['y'][:train_size].values.reshape(-1,1))
    data['y_scaled'] = scaler.transform(data[['y']])

    def create_sequences(values, time_steps=seq_len):
        X, y = [], []
        for i in range(len(values) - time_steps):
            X.append(values[i:(i + time_steps)])
            y.append(values[i + time_steps])
        return np.array(X), np.array(y)

    values = data['y_scaled'].values
    X, y = create_sequences(values, seq_len)
    split = int(len(X)*0.8)
    X_train, X_test = X[:split], X[split:]
    y_train, y_test = y[:split], y[split:]
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1)).astype(np.float32)
    X_test  = X_test.reshape((X_test.shape[0], X_test.shape[1], 1)).astype(np.float32)
    y_train = y_train.astype(np.float32)
    y_test  = y_test.astype(np.float32)

    model = Sequential([
        Conv1D(filters=64, kernel_size=2, activation='relu', padding='causal', input_shape=(seq_len,1)),
        SpatialDropout1D(0.2),
        Conv1D(filters=32, kernel_size=2, activation='relu', padding='causal'),
        Flatten(),
        Dense(1)
    ])
    model.compile(optimizer=Adam(1e-3), loss='mse')

    checkpoint_path = f"best_tcn_{city_name}.weights.h5"
    callbacks = [
        EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=0),
        ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, save_weights_only=True, verbose=0),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=0)
    ]

    history = model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_split=0.1,
        shuffle=False,
        callbacks=callbacks,
        verbose=0
    )
    model.load_weights(checkpoint_path)
    y_pred = model.predict(X_test)
    y_test_inv = scaler.inverse_transform(y_test.reshape(-1,1))
    y_pred_inv = scaler.inverse_transform(y_pred)
    mae = mean_absolute_error(y_test_inv, y_pred_inv)
    rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
    smape_val = 100 * np.mean(2*np.abs(y_pred_inv - y_test_inv)/(np.abs(y_test_inv)+np.abs(y_pred_inv)+1e-8))
    accuracy = 100 - smape_val
    return {
        "City": city_name,
        "MAE": mae,
        "RMSE": rmse,
        "SMAPE": smape_val,
        "Accuracy": accuracy,
        "y_test": y_test_inv,
        "y_pred": y_pred_inv,
        "history": history,
        "model": model,
        "scaler": scaler,
        "X_test": X_test,
        "y_test_scaled": y_test
    }

res_mashhad_tcn = run_tcn(
    "Mashhad_CO_Median.csv",
    "Mashhad"
)

res_seoul_tcn = run_tcn(
    "Seoul_Hybrid_Daily_Clean.csv",
    "Seoul"
)

results_df = pd.DataFrame([
{"City": res_mashhad_tcn["City"], "MAE": res_mashhad_tcn["MAE"], "RMSE": res_mashhad_tcn["RMSE"], "SMAPE": res_mashhad_tcn["SMAPE"], "Accuracy": res_mashhad_tcn["Accuracy"]},
{"City": res_seoul_tcn["City"], "MAE": res_seoul_tcn["MAE"], "RMSE": res_seoul_tcn["RMSE"], "SMAPE": res_seoul_tcn["SMAPE"], "Accuracy": res_seoul_tcn["Accuracy"]}
])
print("\n=========== FINAL TCN COMPARISON ===========")
print(results_df)
res_uni = res_mashhad_tcn.copy()
plt.figure(figsize=(14,6))
plt.plot(res_mashhad_tcn["y_test"], label="Mashhad Real", color='black')
plt.plot(res_mashhad_tcn["y_pred"], label="Mashhad Pred", color='blue')
plt.plot(res_seoul_tcn["y_test"], label="Seoul Real", color='green')
plt.plot(res_seoul_tcn["y_pred"], label="Seoul Pred", color='red')
plt.title("TCN Forecast for CO - Mashhad & Seoul")
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#
# =========== FINAL TCN COMPARISON ===========
#       City       MAE      RMSE      SMAPE   Accuracy
# 0  Mashhad  0.067599  0.098647   5.815499  94.184502
# 1    Seoul  0.033192  0.052994  19.678080  80.321922

# %% [markdown]
# **multivarable TCN**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, SpatialDropout1D, Flatten
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

SEED = 42
import os, random
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

def run_tcn_multivariate(file_path, city_name, seq_len=7, epochs=50, batch_size=16):
    df = pd.read_csv(file_path)
    df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

    features = ['CO', 'Temp_Avg', 'Humidity', 'WindSpeed_Avg', 'Precipitation']

    missing_cols = [col for col in features if col not in df.columns]
    if missing_cols:
        raise SystemExit(f"ستون‌های {missing_cols} در دیتاست {city_name} پیدا نشدند.")

    df = df.dropna(subset=features).reset_index(drop=True)
    data = df[features].values

    scaler_x = MinMaxScaler()
    scaler_y = MinMaxScaler()

    train_size = int(len(data) * 0.8)

    scaler_x.fit(data[:train_size])
    scaler_y.fit(data[:train_size, 0].reshape(-1, 1))

    data_scaled = scaler_x.transform(data)

    def create_sequences_multi(dataset, time_steps):
        X, y = [], []
        for i in range(len(dataset) - time_steps):
            X.append(dataset[i:(i + time_steps), :])
            y.append(dataset[i + time_steps, 0])
        return np.array(X), np.array(y)

    X, y = create_sequences_multi(data_scaled, seq_len)

    split = int(len(X) * 0.8)
    X_train, X_test = X[:split], X[split:]
    y_train, y_test = y[:split], y[split:]

    n_features = X_train.shape[2]

    model = Sequential([
        Conv1D(filters=64, kernel_size=2, activation='relu', padding='causal', input_shape=(seq_len, n_features)),
        SpatialDropout1D(0.2),
        Conv1D(filters=32, kernel_size=2, activation='relu', padding='causal'),
        Flatten(),
        Dense(1)
    ])
    model.compile(optimizer=Adam(1e-3), loss='mse')

    checkpoint_path = f"best_tcn_multi_{city_name}.weights.h5"
    callbacks = [
        EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=0),
        ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, save_weights_only=True, verbose=0),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=0)
    ]

    model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_split=0.1,
        shuffle=False,
        callbacks=callbacks,
        verbose=0
    )

    model.load_weights(checkpoint_path)
    y_pred = model.predict(X_test)

    y_test_inv = scaler_y.inverse_transform(y_test.reshape(-1,1))
    y_pred_inv = scaler_y.inverse_transform(y_pred)

    mae = mean_absolute_error(y_test_inv, y_pred_inv)
    rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
    smape_val = 100 * np.mean(2*np.abs(y_pred_inv - y_test_inv)/(np.abs(y_test_inv)+np.abs(y_pred_inv)+1e-8))
    accuracy = 100 - smape_val

    return {
        "City": city_name,
        "MAE": mae,
        "RMSE": rmse,
        "SMAPE": smape_val,
        "Accuracy": accuracy,
        "y_test": y_test_inv.flatten(),
        "y_pred": y_pred_inv.flatten()
    }

res_mashhad_multi = run_tcn_multivariate(
    "Mashhad_CO_Median.csv",
    "Mashhad"
)
print(f"Mashhad Multivariate TCN Results - MAE: {res_mashhad['MAE']:.3f}, RMSE: {res_mashhad['RMSE']:.3f}, Accuracy: {res_mashhad['Accuracy']:.2f}%")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Mashhad Multivariate TCN Results - MAE: 0.068, RMSE: 0.099, Accuracy: 94.18%

# %%
import matplotlib.pyplot as plt
import numpy as np

metrics = ["MAE", "RMSE"]

uni = [
    res_mashhad["MAE"],
    res_mashhad["RMSE"]
]

multi = [
    res_mashhad_multi["MAE"],
    res_mashhad_multi["RMSE"]
]

x = np.arange(len(metrics))
width = 0.35

plt.figure(figsize=(6,4))

plt.bar(x-width/2, uni, width, label="UniTCN")
plt.bar(x+width/2, multi, width, label="MultiTCN")

plt.xticks(x, metrics)
plt.ylabel("Error (mg/m³)")
plt.legend()

plt.tight_layout()
plt.show()

# %%
print("Difference MAE =", abs(res_uni["MAE"]-res_multi["MAE"]))
print("Difference RMSE =", abs(res_uni["RMSE"]-res_multi["RMSE"]))
print("Difference SMAPE =", abs(res_uni["SMAPE"]-res_multi["SMAPE"]))
# Out:
# Difference MAE = 0.0016058035183498937
# Difference RMSE = 0.0016441149811301792
# Difference SMAPE = 0.12812595910409996

# %%
import matplotlib.pyplot as plt
import numpy as np

#=========================
# UniTCN
#=========================
y_true_uni = np.asarray(res_uni["y_test"]).flatten()
y_pred_uni = np.asarray(res_uni["y_pred"]).flatten()

#=========================
# MultiTCN
#=========================
y_true_multi = np.asarray(res_multi["y_test"]).flatten()
y_pred_multi = np.asarray(res_multi["y_pred"]).flatten()


xmin = min(y_true_uni.min(), y_true_multi.min())
xmax = max(y_true_uni.max(), y_true_multi.max())

plt.figure(figsize=(6.5,6))

# UniTCN
plt.scatter(
    y_true_uni,
    y_pred_uni,
    s=18,
    alpha=0.45,
    color="#1f77b4",
    label="UniTCN"
)

# MultiTCN
plt.scatter(
    y_true_multi,
    y_pred_multi,
    s=18,
    alpha=0.45,
    color="#d62728",
    label="MultiTCN"
)

plt.plot(
    [xmin, xmax],
    [xmin, xmax],
    'k--',
    linewidth=1.5,
    label="Perfect Prediction"
)

plt.xlabel("Observed CO (mg/m³)", fontsize=11)
plt.ylabel("Predicted CO (mg/m³)", fontsize=11)


plt.grid(alpha=0.3)

plt.legend(frameon=True)

plt.gca().set_aspect('equal', adjustable='box')

plt.tight_layout()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

y_test = np.array(res_mashhad["y_test"]).ravel()
y_pred = np.array(res_mashhad["y_pred"]).ravel()

plt.figure(figsize=(12, 5))
plt.plot(y_test, label="Actual CO", linewidth=2)
plt.plot(y_pred, label="Predicted CO", linestyle="--")
plt.xlabel("Time (Days)")
plt.ylabel("CO Concentration (mg/m³)")
plt.title("Actual vs Predicted CO (Test Set) - Mashhad")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()

plt.savefig("actual_vs_pred_mashhad.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# **multiStep**

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error

def recursive_multistep_forecast(results, steps=3):

    model = results["model"]
    X_test = results["X_test"]
    y_test = results["y_test_scaled"]
    scaler = results["scaler"]

    y_true_all = []
    y_pred_all = []

    for i in range(len(X_test)-steps):

        current_seq = X_test[i:i+1].copy()

        preds = []

        for _ in range(steps):

            pred = model.predict(current_seq, verbose=0)

            preds.append(pred[0,0])

            current_seq = np.concatenate(
                [current_seq[:,1:,:],
                 pred.reshape(1,1,1)],
                axis=1
            )

        y_pred_all.append(preds)
        y_true_all.append(y_test[i:i+steps])

    y_pred_all=np.array(y_pred_all)
    y_true_all=np.array(y_true_all)

    y_pred_inv=scaler.inverse_transform(y_pred_all)
    y_true_inv=scaler.inverse_transform(y_true_all)

    mae=mean_absolute_error(y_true_inv,y_pred_inv)
    rmse=np.sqrt(mean_squared_error(y_true_inv,y_pred_inv))

    smape=100*np.mean(
        2*np.abs(y_true_inv-y_pred_inv)/
        (np.abs(y_true_inv)+np.abs(y_pred_inv)+1e-8)
    )

    return {
        "MAE":mae,
        "RMSE":rmse,
        "SMAPE":smape,
        "y_true":y_true_inv,
        "y_pred":y_pred_inv
    }

# %%
result_1 = {
    "MAE":res_mashhad["MAE"],
    "RMSE":res_mashhad["RMSE"],
    "SMAPE":res_mashhad["SMAPE"]
}

result_3 = recursive_multistep_forecast(
    res_mashhad,
    steps=3
)

result_7 = recursive_multistep_forecast(
    res_mashhad,
    steps=7
)

# %%
comparison = pd.DataFrame({

    "Forecast Horizon":[
        "1-Day",
        "3-Day",
        "7-Day"
    ],

    "MAE":[
        result_1["MAE"],
        result_3["MAE"],
        result_7["MAE"]
    ],

    "RMSE":[
        result_1["RMSE"],
        result_3["RMSE"],
        result_7["RMSE"]
    ],

    "SMAPE (%)":[
        result_1["SMAPE"],
        result_3["SMAPE"],
        result_7["SMAPE"]
    ]

})

comparison=comparison.round(4)

print(comparison)
# Out:
#   Forecast Horizon     MAE    RMSE  SMAPE (%)
# 0            1-Day  0.0676  0.0986     5.8155
# 1            3-Day  0.0763  0.1061     6.5749
# 2            7-Day  0.0787  0.1091     6.7862

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))

plt.plot(
    comparison["Forecast Horizon"],
    comparison["MAE"],
    marker='o',
    linewidth=2,
    label="MAE"
)

plt.plot(
    comparison["Forecast Horizon"],
    comparison["RMSE"],
    marker='s',
    linewidth=2,
    label="RMSE"
)

plt.xlabel("Forecast Horizon")
plt.ylabel("Error")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score

fig, axes = plt.subplots(1,3,figsize=(17,5))

datasets = [
    (
        res_mashhad["y_test"].flatten(),
        res_mashhad["y_pred"].flatten(),
        "1-Day Ahead",
        "tab:blue",
        res_mashhad["MAE"],
        res_mashhad["RMSE"],
        res_mashhad["SMAPE"]
    ),
    (
        result_3["y_true"].flatten(),
        result_3["y_pred"].flatten(),
        "3-Day Ahead",
        "tab:orange",
        result_3["MAE"],
        result_3["RMSE"],
        result_3["SMAPE"]
    ),
    (
        result_7["y_true"].flatten(),
        result_7["y_pred"].flatten(),
        "7-Day Ahead",
        "tab:green",
        result_7["MAE"],
        result_7["RMSE"],
        result_7["SMAPE"]
    )
]

for ax,(y_true,y_pred,title,color,mae,rmse,smape) in zip(axes,datasets):

    ax.scatter(
        y_true,
        y_pred,
        s=18,
        color=color,
        alpha=0.65
    )

    mn=min(y_true.min(),y_pred.min())
    mx=max(y_true.max(),y_pred.max())

    ax.plot([mn,mx],[mn,mx],
            'k--',
            lw=1.4,
            label="Perfect Prediction")

    r2=r2_score(y_true,y_pred)

    text = (
        f"MAE = {mae:.4f}\n"
        f"RMSE = {rmse:.4f}\n"
        f"SMAPE = {smape:.2f}"
    )

    ax.text(
        0.03,
        0.97,
        text,
        transform=ax.transAxes,
        fontsize=9,
        verticalalignment='top',
        bbox=dict(facecolor='white',
                  edgecolor='gray',
                  alpha=0.9)
    )

    ax.set_title(title,fontsize=12)

    ax.set_xlabel("Observed CO (mg/m³)")

    if ax==axes[0]:
        ax.set_ylabel("Predicted CO (mg/m³)")

    ax.grid(alpha=0.3)

    ax.set_aspect('equal', adjustable='box')

plt.tight_layout()

plt.savefig(
    "Multistep_Scatter_Comparison.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
# ===================== figure 7 , 8  =====================
import numpy as np
import matplotlib.pyplot as plt

if 'res_mashhad' not in globals():
    raise NameError("Variable 'res_mashhad' not found. Run run_tcn() first.")

if ('y_test' not in res_mashhad) or ('y_pred' not in res_mashhad):
    raise KeyError("'y_test' or 'y_pred' not found in res_mashhad output.")

y_test = np.asarray(res_mashhad['y_test']).reshape(-1)   # Actual values
y_pred = np.asarray(res_mashhad['y_pred']).reshape(-1)   # Predicted values

residuals = y_test - y_pred

print("y_test shape:", y_test.shape,
      "| y_pred shape:", y_pred.shape,
      "| residuals shape:", residuals.shape)
print("Residual statistics -> mean:", residuals.mean(),
      "std:", residuals.std(),
      "min:", residuals.min(),
      "max:", residuals.max())


plt.figure(figsize=(14,5))
plt.plot(residuals, linewidth=1)
plt.axhline(0, linestyle='--')

plt.xlabel("Time (Days)")
plt.ylabel("Residual (Actual - Predicted CO)")
plt.title(" Temporal variation of residuals for the TCN model (test set)")

plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(7,5))
plt.hist(residuals, bins=30, edgecolor='black', alpha=0.85)
plt.axvline(0, linestyle='--')

plt.xlabel("Residual (Actual - Predicted CO)")
plt.ylabel("Frequency")
plt.title(" Distribution of residuals for the TCN model (test set)")

plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# y_test shape: (263,) | y_pred shape: (263,) | residuals shape: (263,)
# Residual statistics -> mean: 0.005199824 std: 0.09850956 min: -0.39036936 max: 0.38542807

# %%
import numpy as np
import matplotlib.pyplot as plt

y_test = np.asarray(res_mashhad['y_test']).reshape(-1)
y_pred = np.asarray(res_mashhad['y_pred']).reshape(-1)

plt.figure(figsize=(6,6))

plt.scatter(
    y_test,
    y_pred,
    s=18,
    alpha=0.75,
    edgecolors='black'
)

min_val = min(y_test.min(), y_pred.min())
max_val = max(y_test.max(), y_pred.max())

plt.plot(
    [min_val, max_val],
    [min_val, max_val],
    'r--',
    linewidth=2,
    label='Ideal prediction'
)

plt.xlabel("Observed CO concentration (mg/m³)", fontsize=11)
plt.ylabel("Predicted CO concentration (mg/m³)", fontsize=11)

plt.legend()

plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

plt.figure(figsize=(7,6))

stats.probplot(residuals, dist="norm", plot=plt)

plt.title("Normal Q-Q Plot of Residuals")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

train_loss = history.history['loss']
val_loss   = history.history['val_loss']

best_epoch = np.argmin(val_loss) + 1

plt.figure(figsize=(8,5))

plt.plot(train_loss,
         linewidth=2,
         label='Training Loss')

plt.plot(val_loss,
         linewidth=2,
         label='Validation Loss')

plt.axvline(best_epoch-1,
            color='gray',
            linestyle='--',
            linewidth=1.5)

plt.scatter(best_epoch-1,
            val_loss[best_epoch-1],
            s=70,
            color='red',
            zorder=5)

plt.text(best_epoch,
         val_loss[best_epoch-1]*1.02,
         f'Best Epoch = {best_epoch}',
         fontsize=10)

plt.xlabel("Epoch", fontsize=12)
plt.ylabel("Loss (MSE)")

plt.grid(alpha=0.25)

plt.legend(frameon=False)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# -----------------------------
# Forecast Horizons
# -----------------------------
horizons = ["1-Day", "3-Day", "7-Day"]

mae = [
    result_1["MAE"],
    result_3["MAE"],
    result_7["MAE"]
]

rmse = [
    result_1["RMSE"],
    result_3["RMSE"],
    result_7["RMSE"]
]

smape = [
    result_1["SMAPE"],
    result_3["SMAPE"],
    result_7["SMAPE"]
]


fig, ax1 = plt.subplots(figsize=(8,5))


ax1.plot(
    horizons,
    mae,
    marker='o',
    linewidth=2,
    label="MAE"
)

ax1.plot(
    horizons,
    rmse,
    marker='s',
    linewidth=2,
    label="RMSE"
)

ax1.set_xlabel("Forecast Horizon", fontsize=12)
ax1.set_ylabel("Error (mg/m³)", fontsize=12)

ax1.grid(alpha=0.3)

ax2 = ax1.twinx()

ax2.plot(
    horizons,
    smape,
    marker='^',
    linewidth=2,
    linestyle='--',
    label="SMAPE"
)

ax2.set_ylabel("SMAPE (%)", fontsize=12)


lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()

ax1.legend(
    lines1 + lines2,
    labels1 + labels2,
    loc="upper left"
)

plt.tight_layout()

plt.savefig(
    "Forecast_Horizon_Performance.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# model 6
#
# # **Hybrid Prophet–LSTM**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from prophet import Prophet

SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

def hybrid_prophet_lstm(file_path, city_name, seq_len=7, epochs=50, batch_size=16):
    df = pd.read_csv(file_path)
    df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
    if 'CO' not in df.columns:
        raise SystemExit(f"ستون 'CO' پیدا نشد در {city_name}")
    data = df[['Date','CO']].rename(columns={'Date':'ds','CO':'y'})

    prophet_train_idx = int(len(data)*0.8)
    train_prophet = data.iloc[:prophet_train_idx]
    test_prophet = data.iloc[prophet_train_idx:]

    model_prophet = Prophet(daily_seasonality=True, yearly_seasonality=True)
    model_prophet.fit(train_prophet)

    future = pd.DataFrame({"ds": data['ds']})
    forecast = model_prophet.predict(future)
    residuals = data['y'].values - forecast['yhat'].values
    residuals = residuals.reshape(-1,1)
    scaler = MinMaxScaler()
    scaler.fit(residuals[:prophet_train_idx])
    residuals_scaled = scaler.transform(residuals)
    def create_sequences(values, time_steps=seq_len):
        X, y = [], []
        for i in range(len(values) - time_steps):
            X.append(values[i:i+time_steps])
            y.append(values[i+time_steps])
        return np.array(X), np.array(y)

    X, y = create_sequences(residuals_scaled, seq_len)
    split = int(len(X)*0.8)
    X_train, X_test = X[:split], X[split:]
    y_train, y_test = y[:split], y[split:]

    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
    X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
    tf.keras.backend.clear_session()
    model = Sequential([
        Input(shape=(seq_len,1)),
        LSTM(64, return_sequences=True),
        Dropout(0.2),
        LSTM(32),
        Dense(1)
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(1e-3), loss='mse')

    checkpoint_path = f"best_hybrid_{city_name}.weights.h5"
    callbacks = [
        EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
        ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, save_weights_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
    ]

    history = model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_split=0.1,
        shuffle=False,
        callbacks=callbacks,
        verbose=1
    )
    model.load_weights(checkpoint_path)

    y_pred_scaled = model.predict(X_test)
    y_pred_residual = scaler.inverse_transform(y_pred_scaled)
    y_test_total = data['y'].values[len(data)-len(y_test):]
    y_pred_total = forecast['yhat'].values[-len(y_test):] + y_pred_residual.ravel()

    mae = mean_absolute_error(y_test_total, y_pred_total)
    rmse = np.sqrt(mean_squared_error(y_test_total, y_pred_total))
    smape_val = 100*np.mean(2*np.abs(y_pred_total - y_test_total)/(np.abs(y_test_total)+np.abs(y_pred_total)+1e-8))
    accuracy = 100 - smape_val

    print(f"\n📊 Hybrid Prophet-LSTM - {city_name}")
    print(f"MAE: {mae:.4f}, RMSE: {rmse:.4f}, SMAPE: {smape_val:.2f}%, Accuracy: {accuracy:.2f}%")

    plt.figure(figsize=(12,6))
    plt.plot(y_test_total, label='Real CO', color='black')
    plt.plot(y_pred_total, label='Predicted CO', color='red')
    plt.title(f"Hybrid Prophet-LSTM Forecast for {city_name}")
    plt.xlabel("Days")
    plt.ylabel("CO")
    plt.legend()
    plt.show()
    return {
      "City": city_name,
      "MAE": mae,
      "RMSE": rmse,
      "SMAPE": smape_val,
      "Accuracy": accuracy,
      "y_test": y_test_total.reshape(-1, 1),
      "y_pred": y_pred_total.reshape(-1, 1),
      "summary": f"Hybrid Prophet-LSTM {city_name} -> MAE: {mae:.4f}, RMSE: {rmse:.4f}, SMAPE: {smape_val:.2f}%, Accuracy: {accuracy:.2f}%"
    }


res_mashhad_hybrid = hybrid_prophet_lstm(
    "Mashhad_CO_Median.csv",
    "Mashhad"
)

res_seoul_hybrid = hybrid_prophet_lstm(
    "Seoul_Hybrid_Daily_Clean.csv",
    "Seoul"
)

results_df = pd.DataFrame([
    res_mashhad_hybrid,
    res_seoul_hybrid
])

print("\n=========== FINAL Hybrid Prophet-LSTM COMPARISON ===========")
print(results_df)
# Out:
# Epoch 1/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0350 - val_loss: 0.0142 - learning_rate: 0.0010
# Epoch 2/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0190 - val_loss: 0.0141 - learning_rate: 0.0010
# Epoch 3/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0186 - val_loss: 0.0140 - learning_rate: 0.0010
# Epoch 4/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0185 - val_loss: 0.0139 - learning_rate: 0.0010
# Epoch 5/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0184 - val_loss: 0.0139 - learning_rate: 0.0010
# Epoch 6/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0183 - val_loss: 0.0138 - learning_rate: 0.0010
# Epoch 7/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0183 - val_loss: 0.0138 - learning_rate: 0.0010
# Epoch 8/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0182 - val_loss: 0.0141 - learning_rate: 0.0010
# Epoch 9/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0180 - val_loss: 0.0136 - learning_rate: 0.0010
# Epoch 10/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0180 - val_loss: 0.0137 - learning_rate: 0.0010
# Epoch 11/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0178 - val_loss: 0.0136 - learning_rate: 0.0010
# Epoch 12/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0178 - val_loss: 0.0135 - learning_rate: 0.0010
# Epoch 13/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0177 - val_loss: 0.0136 - learning_rate: 0.0010
# Epoch 14/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0176 - val_loss: 0.0135 - learning_rate: 0.0010
# Epoch 15/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0173 - val_loss: 0.0123 - learning_rate: 5.0000e-04
# Epoch 16/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0174 - val_loss: 0.0124 - learning_rate: 5.0000e-04
# Epoch 17/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0172 - val_loss: 0.0123 - learning_rate: 5.0000e-04
# Epoch 18/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0174 - val_loss: 0.0122 - learning_rate: 5.0000e-04
# Epoch 19/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0170 - val_loss: 0.0120 - learning_rate: 5.0000e-04
# Epoch 20/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0171 - val_loss: 0.0121 - learning_rate: 5.0000e-04
# Epoch 21/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0172 - val_loss: 0.0120 - learning_rate: 5.0000e-04
# Epoch 22/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0169 - val_loss: 0.0119 - learning_rate: 5.0000e-04
# Epoch 23/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0171 - val_loss: 0.0118 - learning_rate: 5.0000e-04
# Epoch 24/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0170 - val_loss: 0.0118 - learning_rate: 5.0000e-04
# Epoch 25/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0171 - val_loss: 0.0117 - learning_rate: 5.0000e-04
# Epoch 26/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0167 - val_loss: 0.0116 - learning_rate: 5.0000e-04
# Epoch 27/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0168 - val_loss: 0.0116 - learning_rate: 5.0000e-04
# Epoch 28/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0169 - val_loss: 0.0114 - learning_rate: 5.0000e-04
# Epoch 29/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0169 - val_loss: 0.0114 - learning_rate: 5.0000e-04
# Epoch 30/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0167 - val_loss: 0.0113 - learning_rate: 5.0000e-04
# Epoch 31/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0167 - val_loss: 0.0112 - learning_rate: 5.0000e-04
# Epoch 32/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0167 - val_loss: 0.0112 - learning_rate: 5.0000e-04
# Epoch 33/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0165 - val_loss: 0.0110 - learning_rate: 5.0000e-04
# Epoch 34/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0165 - val_loss: 0.0111 - learning_rate: 5.0000e-04
# Epoch 35/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0162 - val_loss: 0.0109 - learning_rate: 5.0000e-04
# Epoch 36/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0163 - val_loss: 0.0108 - learning_rate: 5.0000e-04
# Epoch 37/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0163 - val_loss: 0.0109 - learning_rate: 5.0000e-04
# Epoch 38/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0164 - val_loss: 0.0107 - learning_rate: 5.0000e-04
# Epoch 39/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0164 - val_loss: 0.0107 - learning_rate: 5.0000e-04
# Epoch 40/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0164 - val_loss: 0.0107 - learning_rate: 5.0000e-04
# Epoch 41/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0163 - val_loss: 0.0106 - learning_rate: 5.0000e-04
# Epoch 42/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0164 - val_loss: 0.0106 - learning_rate: 5.0000e-04
# Epoch 43/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0164 - val_loss: 0.0105 - learning_rate: 5.0000e-04
# Epoch 44/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0162 - val_loss: 0.0105 - learning_rate: 5.0000e-04
# Epoch 45/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0162 - val_loss: 0.0105 - learning_rate: 5.0000e-04
# Epoch 46/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0163 - val_loss: 0.0106 - learning_rate: 5.0000e-04
# Epoch 47/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0162 - val_loss: 0.0105 - learning_rate: 5.0000e-04
# Epoch 48/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0162 - val_loss: 0.0104 - learning_rate: 5.0000e-04
# Epoch 49/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0162 - val_loss: 0.0106 - learning_rate: 5.0000e-04
# Epoch 50/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0162 - val_loss: 0.0105 - learning_rate: 5.0000e-04
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#
# 📊 Hybrid Prophet-LSTM - Mashhad
# MAE: 0.0699, RMSE: 0.0976, SMAPE: 6.02%, Accuracy: 93.98%
# Epoch 1/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0147 - val_loss: 0.0069 - learning_rate: 0.0010
# Epoch 2/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0100 - val_loss: 0.0066 - learning_rate: 0.0010
# Epoch 3/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0097 - val_loss: 0.0063 - learning_rate: 0.0010
# Epoch 4/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0094 - val_loss: 0.0058 - learning_rate: 0.0010
# Epoch 5/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0088 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 6/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0080 - val_loss: 0.0043 - learning_rate: 0.0010
# Epoch 7/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0072 - val_loss: 0.0036 - learning_rate: 0.0010
# Epoch 8/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0065 - val_loss: 0.0032 - learning_rate: 0.0010
# Epoch 9/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0061 - val_loss: 0.0031 - learning_rate: 0.0010
# Epoch 10/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0057 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 11/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0056 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 12/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0054 - val_loss: 0.0029 - learning_rate: 0.0010
# Epoch 13/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0052 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 14/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0051 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 15/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0051 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 16/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0050 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 17/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0050 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 18/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0049 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 19/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0048 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 20/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0049 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 21/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0048 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 22/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0047 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 23/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0047 - val_loss: 0.0029 - learning_rate: 5.0000e-04
# Epoch 24/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0048 - val_loss: 0.0028 - learning_rate: 5.0000e-04
# Epoch 25/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0047 - val_loss: 0.0028 - learning_rate: 5.0000e-04
# Epoch 26/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0048 - val_loss: 0.0029 - learning_rate: 5.0000e-04
# Epoch 27/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0048 - val_loss: 0.0028 - learning_rate: 5.0000e-04
# Epoch 28/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0047 - val_loss: 0.0026 - learning_rate: 2.5000e-04
# Epoch 29/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0046 - val_loss: 0.0027 - learning_rate: 2.5000e-04
# Epoch 30/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0046 - val_loss: 0.0026 - learning_rate: 2.5000e-04
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#
# 📊 Hybrid Prophet-LSTM - Seoul
# MAE: 0.0388, RMSE: 0.0564, SMAPE: 23.57%, Accuracy: 76.43%
# =========== FINAL Hybrid Prophet-LSTM COMPARISON ===========
#       City       MAE      RMSE      SMAPE   Accuracy  \
# 0  Mashhad  0.069878  0.097570   6.017525  93.982475
# 1    Seoul  0.038770  0.056353  23.572952  76.427048
#
#                                               y_test  \
# 0  [[1.07], [1.03], [1.09], [1.09], [1.06], [1.03...
# 1  [[0.125097125], [0.076590077], [0.076590077], ...
#
#                                               y_pred  \
# 0  [[1.1170822292814742], [1.0944274536029996], [...
# 1  [[0.12036541430987452], [0.14761587586860037],...
#
#                                              summary
# 0  Hybrid Prophet-LSTM Mashhad -> MAE: 0.0699, RM...
# 1  Hybrid Prophet-LSTM Seoul -> MAE: 0.0388, RMSE...

# %% [markdown]
# #  Performance of models across low, medium, and high CO levels

# %%
res_mashhad_lin = run_linear_no_leak("Mashhad_CO_Median.csv", "Mashhad", col_name="CO")
res_seoul_lin  = run_linear_no_leak("Seoul_Hybrid_Daily_Clean.csv", "Seoul", col_name="CO")

res_mashhad_prophet = run_prophet("Mashhad_CO_Median.csv", "Mashhad")
res_seoul_prophet  = run_prophet("Seoul_Hybrid_Daily_Clean.csv", "Seoul")

res_mashhad_lstm = run_lstm("Mashhad_CO_Median.csv", "Mashhad")
res_seoul_lstm  = run_lstm("Seoul_Hybrid_Daily_Clean.csv", "Seoul")

res_mashhad_bilstm = run_bilstm("Mashhad_CO_Median.csv", "Mashhad")
res_seoul_bilstm  = run_bilstm("Seoul_Hybrid_Daily_Clean.csv", "Seoul")

res_mashhad_tcn = run_tcn("Mashhad_CO_Median.csv", "Mashhad")
res_seoul_tcn  = run_tcn("Seoul_Hybrid_Daily_Clean.csv", "Seoul")

res_mashhad_hybrid = hybrid_prophet_lstm("Mashhad_CO_Median.csv", "Mashhad")
res_seoul_hybrid  = hybrid_prophet_lstm("Seoul_Hybrid_Daily_Clean.csv", "Seoul")


models = [

    ("Linear Regression", {"Mashhad": res_mashhad_lin, "Seoul": res_seoul_lin}),
    ("Prophet", {"Mashhad": res_mashhad_prophet, "Seoul": res_seoul_prophet}),
    ("LSTM", {"Mashhad": res_mashhad_lstm, "Seoul": res_seoul_lstm}),
    ("Bi-LSTM", {"Mashhad": res_mashhad_bilstm, "Seoul": res_seoul_bilstm}),
    ("TCN", {"Mashhad": res_mashhad_tcn, "Seoul": res_seoul_tcn}),
    ("Hybrid Prophet-LSTM", {"Mashhad": res_mashhad_hybrid, "Seoul": res_seoul_hybrid}),
]

for model_name, cities_dict in models:
    for city, res_dict in cities_dict.items():
        evaluate_levels_from_dict(res_dict, city, model_name)
# Out:
# =========== Running Linear Regression for Mashhad ===========
# MAE: 0.0675
# RMSE: 0.0981
# SMAPE: 5.81%
# Accuracy: 94.19%
#
# =========== Running Linear Regression for Seoul ===========
# MAE: 0.0350
# RMSE: 0.0540
# SMAPE: 21.00%
# Accuracy: 79.00%
#
# =========== Running Prophet for Mashhad ===========
# MAE: 0.0794
# RMSE: 0.1065
# SMAPE: 6.84%
# Accuracy: 93.16%
# =========== Running Prophet for Seoul ===========
# MAE: 0.0674
# RMSE: 0.0864
# SMAPE: 38.02%
# Accuracy: 61.98%
# Epoch 1/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.0435 - val_loss: 0.0093 - learning_rate: 0.0010
# Epoch 2/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0175 - val_loss: 0.0092 - learning_rate: 0.0010
# Epoch 3/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0174 - val_loss: 0.0091 - learning_rate: 0.0010
# Epoch 4/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0173 - val_loss: 0.0091 - learning_rate: 0.0010
# Epoch 5/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0172 - val_loss: 0.0091 - learning_rate: 0.0010
# Epoch 6/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0170 - val_loss: 0.0091 - learning_rate: 0.0010
# Epoch 7/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0169 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 8/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0164 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 9/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0165
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0164 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 10/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0158 - val_loss: 0.0089 - learning_rate: 5.0000e-04
# Epoch 11/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0156 - val_loss: 0.0089 - learning_rate: 5.0000e-04
# Epoch 12/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0152 - val_loss: 0.0089 - learning_rate: 5.0000e-04
# Epoch 13/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0154 - val_loss: 0.0089 - learning_rate: 5.0000e-04
# Epoch 14/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0154 - val_loss: 0.0089 - learning_rate: 5.0000e-04
# Epoch 15/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0154
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0153 - val_loss: 0.0088 - learning_rate: 5.0000e-04
# Epoch 16/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0152 - val_loss: 0.0088 - learning_rate: 2.5000e-04
# Epoch 17/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0151 - val_loss: 0.0087 - learning_rate: 2.5000e-04
# Epoch 18/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0149 - val_loss: 0.0087 - learning_rate: 2.5000e-04
# Epoch 19/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0151 - val_loss: 0.0087 - learning_rate: 2.5000e-04
# Epoch 20/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0151 - val_loss: 0.0087 - learning_rate: 2.5000e-04
# Epoch 21/50
# 53/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0152
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0150 - val_loss: 0.0087 - learning_rate: 2.5000e-04
# Epoch 22/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0150 - val_loss: 0.0087 - learning_rate: 1.2500e-04
# Epoch 23/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0147 - val_loss: 0.0087 - learning_rate: 1.2500e-04
# Epoch 24/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0149 - val_loss: 0.0086 - learning_rate: 1.2500e-04
# Epoch 25/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0148 - val_loss: 0.0086 - learning_rate: 1.2500e-04
# Epoch 26/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0147 - val_loss: 0.0086 - learning_rate: 1.2500e-04
# Epoch 27/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0148 - val_loss: 0.0086 - learning_rate: 1.2500e-04
# Epoch 28/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0146 - val_loss: 0.0086 - learning_rate: 1.2500e-04
# Epoch 29/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0148
# Epoch 29: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0147 - val_loss: 0.0086 - learning_rate: 1.2500e-04
# Epoch 30/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0146 - val_loss: 0.0086 - learning_rate: 6.2500e-05
# Epoch 31/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0148 - val_loss: 0.0086 - learning_rate: 6.2500e-05
# Epoch 32/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0146 - val_loss: 0.0086 - learning_rate: 6.2500e-05
# Epoch 33/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0146 - val_loss: 0.0086 - learning_rate: 6.2500e-05
# Epoch 34/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0145
# Epoch 34: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0145 - val_loss: 0.0086 - learning_rate: 6.2500e-05
# Epoch 35/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0147 - val_loss: 0.0086 - learning_rate: 3.1250e-05
# Epoch 36/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0146 - val_loss: 0.0086 - learning_rate: 3.1250e-05
# Epoch 37/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0146 - val_loss: 0.0086 - learning_rate: 3.1250e-05
# Epoch 38/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0146 - val_loss: 0.0086 - learning_rate: 3.1250e-05
# Epoch 39/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0145
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0145 - val_loss: 0.0086 - learning_rate: 3.1250e-05
# Epoch 40/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0145 - val_loss: 0.0086 - learning_rate: 1.5625e-05
# Epoch 41/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0143 - val_loss: 0.0086 - learning_rate: 1.5625e-05
# Epoch 42/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0144 - val_loss: 0.0086 - learning_rate: 1.5625e-05
# Epoch 43/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0145 - val_loss: 0.0086 - learning_rate: 1.5625e-05
# Epoch 44/50
# 55/59 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0146
# Epoch 44: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0145 - val_loss: 0.0086 - learning_rate: 1.5625e-05
# Epoch 45/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0145 - val_loss: 0.0086 - learning_rate: 7.8125e-06
# Epoch 46/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0145 - val_loss: 0.0086 - learning_rate: 7.8125e-06
# Epoch 47/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0145 - val_loss: 0.0086 - learning_rate: 7.8125e-06
# Epoch 48/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0148 - val_loss: 0.0086 - learning_rate: 7.8125e-06
# Epoch 49/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0145
# Epoch 49: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0144 - val_loss: 0.0086 - learning_rate: 7.8125e-06
# Epoch 50/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0145 - val_loss: 0.0085 - learning_rate: 3.9063e-06
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step
#
# 📊 نتایج LSTM برای Mashhad
# MAE: 0.0742, RMSE: 0.1038, SMAPE: 6.38%, Accuracy: 93.62%
# Epoch 1/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0302 - val_loss: 0.0220 - learning_rate: 0.0010
# Epoch 2/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0172 - val_loss: 0.0172 - learning_rate: 0.0010
# Epoch 3/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0167 - val_loss: 0.0146 - learning_rate: 0.0010
# Epoch 4/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0156 - val_loss: 0.0133 - learning_rate: 0.0010
# Epoch 5/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0147 - val_loss: 0.0115 - learning_rate: 0.0010
# Epoch 6/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0137 - val_loss: 0.0096 - learning_rate: 0.0010
# Epoch 7/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0124 - val_loss: 0.0086 - learning_rate: 0.0010
# Epoch 8/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0111 - val_loss: 0.0078 - learning_rate: 0.0010
# Epoch 9/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0100 - val_loss: 0.0069 - learning_rate: 0.0010
# Epoch 10/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0093 - val_loss: 0.0059 - learning_rate: 0.0010
# Epoch 11/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0087 - val_loss: 0.0054 - learning_rate: 0.0010
# Epoch 12/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0082 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 13/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0083 - val_loss: 0.0053 - learning_rate: 0.0010
# Epoch 14/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0080 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 15/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0081 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 16/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0079 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 17/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0077 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 18/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0079 - val_loss: 0.0054 - learning_rate: 0.0010
# Epoch 19/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0078 - val_loss: 0.0054 - learning_rate: 0.0010
# Epoch 20/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0080
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 0.0080 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 21/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0079 - val_loss: 0.0035 - learning_rate: 5.0000e-04
# Epoch 22/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0074 - val_loss: 0.0036 - learning_rate: 5.0000e-04
# Epoch 23/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0074 - val_loss: 0.0036 - learning_rate: 5.0000e-04
# Epoch 24/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0071 - val_loss: 0.0036 - learning_rate: 5.0000e-04
# Epoch 25/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0073 - val_loss: 0.0037 - learning_rate: 5.0000e-04
# Epoch 26/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0073
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0072 - val_loss: 0.0036 - learning_rate: 5.0000e-04
# Epoch 27/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0072 - val_loss: 0.0034 - learning_rate: 2.5000e-04
# Epoch 28/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0072 - val_loss: 0.0034 - learning_rate: 2.5000e-04
# Epoch 29/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0071 - val_loss: 0.0034 - learning_rate: 2.5000e-04
# Epoch 30/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0070 - val_loss: 0.0034 - learning_rate: 2.5000e-04
# Epoch 31/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0070 - val_loss: 0.0034 - learning_rate: 2.5000e-04
# Epoch 32/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0070 - val_loss: 0.0034 - learning_rate: 2.5000e-04
# Epoch 33/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0069 - val_loss: 0.0034 - learning_rate: 2.5000e-04
# Epoch 34/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0070 - val_loss: 0.0034 - learning_rate: 2.5000e-04
# Epoch 35/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0070 - val_loss: 0.0033 - learning_rate: 1.2500e-04
# Epoch 36/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0070 - val_loss: 0.0033 - learning_rate: 1.2500e-04
# Epoch 37/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0070 - val_loss: 0.0033 - learning_rate: 1.2500e-04
# Epoch 38/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0070 - val_loss: 0.0033 - learning_rate: 1.2500e-04
# Epoch 39/50
# 94/99 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0069
# Epoch 39: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0068 - val_loss: 0.0033 - learning_rate: 1.2500e-04
# Epoch 40/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0071 - val_loss: 0.0033 - learning_rate: 6.2500e-05
# Epoch 41/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0069 - val_loss: 0.0033 - learning_rate: 6.2500e-05
# Epoch 42/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0069 - val_loss: 0.0033 - learning_rate: 6.2500e-05
# Epoch 43/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0069 - val_loss: 0.0033 - learning_rate: 6.2500e-05
# Epoch 44/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0070
# Epoch 44: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0069 - val_loss: 0.0033 - learning_rate: 6.2500e-05
# Epoch 45/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0069 - val_loss: 0.0033 - learning_rate: 3.1250e-05
# Epoch 46/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0068 - val_loss: 0.0033 - learning_rate: 3.1250e-05
# Epoch 47/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0069 - val_loss: 0.0033 - learning_rate: 3.1250e-05
# Epoch 48/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0068 - val_loss: 0.0033 - learning_rate: 3.1250e-05
# Epoch 49/50
# 94/99 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0069
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0068 - val_loss: 0.0033 - learning_rate: 3.1250e-05
# Epoch 50/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0068 - val_loss: 0.0033 - learning_rate: 1.5625e-05
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
#
# 📊 نتایج LSTM برای Seoul
# MAE: 0.0361, RMSE: 0.0561, SMAPE: 22.12%, Accuracy: 77.88%
# =========== Bi-LSTM for Mashhad ===========
# Shapes -> X_train: (1048, 7, 1) X_test: (264, 7, 1)
# Epoch 1/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0379
# Epoch 1: val_loss improved from inf to 0.00931, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0377 - val_loss: 0.0093 - learning_rate: 0.0010
# Epoch 2/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0163
# Epoch 2: val_loss did not improve from 0.00931
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0162 - val_loss: 0.0096 - learning_rate: 0.0010
# Epoch 3/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0166
# Epoch 3: val_loss did not improve from 0.00931
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0165 - val_loss: 0.0094 - learning_rate: 0.0010
# Epoch 4/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0164
# Epoch 4: val_loss improved from 0.00931 to 0.00905, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0164 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 5/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0166
# Epoch 5: val_loss improved from 0.00905 to 0.00874, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0165 - val_loss: 0.0087 - learning_rate: 0.0010
# Epoch 6/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0166
# Epoch 6: val_loss improved from 0.00874 to 0.00850, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0165 - val_loss: 0.0085 - learning_rate: 0.0010
# Epoch 7/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0163
# Epoch 7: val_loss improved from 0.00850 to 0.00839, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0163 - val_loss: 0.0084 - learning_rate: 0.0010
# Epoch 8/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0162
# Epoch 8: val_loss improved from 0.00839 to 0.00828, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0161 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 9/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0158
# Epoch 9: val_loss improved from 0.00828 to 0.00820, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0158 - val_loss: 0.0082 - learning_rate: 0.0010
# Epoch 10/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0156
# Epoch 10: val_loss improved from 0.00820 to 0.00813, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0155 - val_loss: 0.0081 - learning_rate: 0.0010
# Epoch 11/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0156
# Epoch 11: val_loss improved from 0.00813 to 0.00808, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0155 - val_loss: 0.0081 - learning_rate: 0.0010
# Epoch 12/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0154
# Epoch 12: val_loss improved from 0.00808 to 0.00801, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0153 - val_loss: 0.0080 - learning_rate: 0.0010
# Epoch 13/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0154
# Epoch 13: val_loss improved from 0.00801 to 0.00796, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0152 - val_loss: 0.0080 - learning_rate: 0.0010
# Epoch 14/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0152
# Epoch 14: val_loss improved from 0.00796 to 0.00791, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0151 - val_loss: 0.0079 - learning_rate: 0.0010
# Epoch 15/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0151
# Epoch 15: val_loss improved from 0.00791 to 0.00786, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0150 - val_loss: 0.0079 - learning_rate: 0.0010
# Epoch 16/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0151
# Epoch 16: val_loss improved from 0.00786 to 0.00783, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0150 - val_loss: 0.0078 - learning_rate: 0.0010
# Epoch 17/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0150
# Epoch 17: val_loss improved from 0.00783 to 0.00779, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0150 - val_loss: 0.0078 - learning_rate: 0.0010
# Epoch 18/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0149
# Epoch 18: val_loss improved from 0.00779 to 0.00775, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0149 - val_loss: 0.0077 - learning_rate: 0.0010
# Epoch 19/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0149
# Epoch 19: val_loss improved from 0.00775 to 0.00770, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0149 - val_loss: 0.0077 - learning_rate: 0.0010
# Epoch 20/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0149
# Epoch 20: val_loss improved from 0.00770 to 0.00768, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0149 - val_loss: 0.0077 - learning_rate: 0.0010
# Epoch 21/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0147
# Epoch 21: val_loss improved from 0.00768 to 0.00766, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0146 - val_loss: 0.0077 - learning_rate: 0.0010
# Epoch 22/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0147
# Epoch 22: val_loss improved from 0.00766 to 0.00762, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0146 - val_loss: 0.0076 - learning_rate: 0.0010
# Epoch 23/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0146
# Epoch 23: val_loss improved from 0.00762 to 0.00759, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0145 - val_loss: 0.0076 - learning_rate: 0.0010
# Epoch 24/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0147
# Epoch 24: val_loss improved from 0.00759 to 0.00753, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0146 - val_loss: 0.0075 - learning_rate: 0.0010
# Epoch 25/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0145
# Epoch 25: val_loss improved from 0.00753 to 0.00748, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0144 - val_loss: 0.0075 - learning_rate: 0.0010
# Epoch 26/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0145
# Epoch 26: val_loss improved from 0.00748 to 0.00747, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0145 - val_loss: 0.0075 - learning_rate: 0.0010
# Epoch 27/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0145
# Epoch 27: val_loss improved from 0.00747 to 0.00743, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0144 - val_loss: 0.0074 - learning_rate: 0.0010
# Epoch 28/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0144
# Epoch 28: val_loss improved from 0.00743 to 0.00741, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0144 - val_loss: 0.0074 - learning_rate: 0.0010
# Epoch 29/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0144
# Epoch 29: val_loss improved from 0.00741 to 0.00735, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0144 - val_loss: 0.0074 - learning_rate: 0.0010
# Epoch 30/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0144
# Epoch 30: val_loss improved from 0.00735 to 0.00733, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0143 - val_loss: 0.0073 - learning_rate: 0.0010
# Epoch 31/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0142
# Epoch 31: val_loss improved from 0.00733 to 0.00729, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0142 - val_loss: 0.0073 - learning_rate: 0.0010
# Epoch 32/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0143
# Epoch 32: val_loss improved from 0.00729 to 0.00726, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0142 - val_loss: 0.0073 - learning_rate: 0.0010
# Epoch 33/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0146
# Epoch 33: val_loss improved from 0.00726 to 0.00724, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0145 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 34/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0143
# Epoch 34: val_loss improved from 0.00724 to 0.00721, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0142 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 35/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0142
# Epoch 35: val_loss improved from 0.00721 to 0.00715, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0141 - val_loss: 0.0072 - learning_rate: 0.0010
# Epoch 36/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0142
# Epoch 36: val_loss improved from 0.00715 to 0.00714, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0141 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 37/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0141
# Epoch 37: val_loss improved from 0.00714 to 0.00711, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0141 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 38/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0141
# Epoch 38: val_loss improved from 0.00711 to 0.00711, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0140 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 39/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0140
# Epoch 39: val_loss improved from 0.00711 to 0.00708, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0139 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 40/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0143
# Epoch 40: val_loss did not improve from 0.00708
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0142 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 41/50
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0141
# Epoch 41: val_loss improved from 0.00708 to 0.00706, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0140 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 42/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0141
# Epoch 42: val_loss improved from 0.00706 to 0.00705, saving model to best_bilstm_Mashhad.weights.h5
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0140 - val_loss: 0.0070 - learning_rate: 0.0010
# Epoch 43/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0139
# Epoch 43: val_loss improved from 0.00705 to 0.00703, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0138 - val_loss: 0.0070 - learning_rate: 5.0000e-04
# Epoch 44/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0138
# Epoch 44: val_loss did not improve from 0.00703
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0137 - val_loss: 0.0070 - learning_rate: 5.0000e-04
# Epoch 45/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0136
# Epoch 45: val_loss improved from 0.00703 to 0.00703, saving model to best_bilstm_Mashhad.weights.h5
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0135 - val_loss: 0.0070 - learning_rate: 5.0000e-04
# Epoch 46/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0138
# Epoch 46: val_loss did not improve from 0.00703
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0137 - val_loss: 0.0070 - learning_rate: 5.0000e-04
# Epoch 47/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0137
# Epoch 47: val_loss did not improve from 0.00703
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0137 - val_loss: 0.0070 - learning_rate: 5.0000e-04
# Epoch 48/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0136
# Epoch 48: val_loss did not improve from 0.00703
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0135 - val_loss: 0.0070 - learning_rate: 2.5000e-04
# Epoch 49/50
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0139
# Epoch 49: val_loss did not improve from 0.00703
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0138 - val_loss: 0.0071 - learning_rate: 2.5000e-04
# Epoch 50/50
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0135
# Epoch 50: val_loss did not improve from 0.00703
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0135 - val_loss: 0.0071 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 45.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step
# MAE: 0.0668, RMSE: 0.0978, SMAPE: 5.74%, Accuracy: 94.26%
# =========== Bi-LSTM for Seoul ===========
# Shapes -> X_train: (1745, 7, 1) X_test: (438, 7, 1)
# Epoch 1/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0241
# Epoch 1: val_loss improved from inf to 0.01739, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - loss: 0.0239 - val_loss: 0.0174 - learning_rate: 0.0010
# Epoch 2/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0144
# Epoch 2: val_loss improved from 0.01739 to 0.01724, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0144 - val_loss: 0.0172 - learning_rate: 0.0010
# Epoch 3/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0135
# Epoch 3: val_loss improved from 0.01724 to 0.01403, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0135 - val_loss: 0.0140 - learning_rate: 0.0010
# Epoch 4/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0122
# Epoch 4: val_loss improved from 0.01403 to 0.01338, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0122 - val_loss: 0.0134 - learning_rate: 0.0010
# Epoch 5/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0116
# Epoch 5: val_loss improved from 0.01338 to 0.01139, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0116 - val_loss: 0.0114 - learning_rate: 0.0010
# Epoch 6/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0108
# Epoch 6: val_loss improved from 0.01139 to 0.01052, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0108 - val_loss: 0.0105 - learning_rate: 0.0010
# Epoch 7/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0106
# Epoch 7: val_loss improved from 0.01052 to 0.00893, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0105 - val_loss: 0.0089 - learning_rate: 0.0010
# Epoch 8/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0099
# Epoch 8: val_loss improved from 0.00893 to 0.00837, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0099 - val_loss: 0.0084 - learning_rate: 0.0010
# Epoch 9/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0094
# Epoch 9: val_loss improved from 0.00837 to 0.00776, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0094 - val_loss: 0.0078 - learning_rate: 0.0010
# Epoch 10/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0091
# Epoch 10: val_loss improved from 0.00776 to 0.00726, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0090 - val_loss: 0.0073 - learning_rate: 0.0010
# Epoch 11/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0086
# Epoch 11: val_loss improved from 0.00726 to 0.00688, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0086 - val_loss: 0.0069 - learning_rate: 0.0010
# Epoch 12/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0084
# Epoch 12: val_loss improved from 0.00688 to 0.00663, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0084 - val_loss: 0.0066 - learning_rate: 0.0010
# Epoch 13/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0082
# Epoch 13: val_loss improved from 0.00663 to 0.00624, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0082 - val_loss: 0.0062 - learning_rate: 0.0010
# Epoch 14/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0078
# Epoch 14: val_loss improved from 0.00624 to 0.00613, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0078 - val_loss: 0.0061 - learning_rate: 0.0010
# Epoch 15/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0076
# Epoch 15: val_loss improved from 0.00613 to 0.00505, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0076 - val_loss: 0.0050 - learning_rate: 0.0010
# Epoch 16/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0077
# Epoch 16: val_loss did not improve from 0.00505
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0077 - val_loss: 0.0056 - learning_rate: 0.0010
# Epoch 17/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0078
# Epoch 17: val_loss did not improve from 0.00505
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0078 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 18/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0074
# Epoch 18: val_loss improved from 0.00505 to 0.00494, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0074 - val_loss: 0.0049 - learning_rate: 0.0010
# Epoch 19/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0078
# Epoch 19: val_loss improved from 0.00494 to 0.00466, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0077 - val_loss: 0.0047 - learning_rate: 0.0010
# Epoch 20/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0075
# Epoch 20: val_loss did not improve from 0.00466
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0075 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 21/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0076
# Epoch 21: val_loss did not improve from 0.00466
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0076 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 22/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0077
# Epoch 22: val_loss did not improve from 0.00466
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0077 - val_loss: 0.0048 - learning_rate: 0.0010
# Epoch 23/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0076
# Epoch 23: val_loss did not improve from 0.00466
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0076 - val_loss: 0.0052 - learning_rate: 0.0010
# Epoch 24/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0075
# Epoch 24: val_loss did not improve from 0.00466
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0075 - val_loss: 0.0051 - learning_rate: 0.0010
# Epoch 25/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0075
# Epoch 25: val_loss improved from 0.00466 to 0.00331, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.0075 - val_loss: 0.0033 - learning_rate: 5.0000e-04
# Epoch 26/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0071
# Epoch 26: val_loss did not improve from 0.00331
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0071 - val_loss: 0.0034 - learning_rate: 5.0000e-04
# Epoch 27/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0072
# Epoch 27: val_loss did not improve from 0.00331
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0072 - val_loss: 0.0035 - learning_rate: 5.0000e-04
# Epoch 28/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0071
# Epoch 28: val_loss did not improve from 0.00331
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0071 - val_loss: 0.0035 - learning_rate: 5.0000e-04
# Epoch 29/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0073
# Epoch 29: val_loss did not improve from 0.00331
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0072 - val_loss: 0.0035 - learning_rate: 5.0000e-04
# Epoch 30/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0072
# Epoch 30: val_loss did not improve from 0.00331
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0072 - val_loss: 0.0035 - learning_rate: 5.0000e-04
# Epoch 31/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0072
# Epoch 31: val_loss improved from 0.00331 to 0.00321, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0072 - val_loss: 0.0032 - learning_rate: 2.5000e-04
# Epoch 32/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0070
# Epoch 32: val_loss did not improve from 0.00321
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0070 - val_loss: 0.0032 - learning_rate: 2.5000e-04
# Epoch 33/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0069
# Epoch 33: val_loss did not improve from 0.00321
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.0069 - val_loss: 0.0032 - learning_rate: 2.5000e-04
# Epoch 34/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0070
# Epoch 34: val_loss did not improve from 0.00321
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0069 - val_loss: 0.0032 - learning_rate: 2.5000e-04
# Epoch 35/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0069
# Epoch 35: val_loss did not improve from 0.00321
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.0069 - val_loss: 0.0033 - learning_rate: 2.5000e-04
# Epoch 36/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0072
# Epoch 36: val_loss did not improve from 0.00321
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0071 - val_loss: 0.0032 - learning_rate: 2.5000e-04
# Epoch 37/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0071
# Epoch 37: val_loss improved from 0.00321 to 0.00319, saving model to best_bilstm_Seoul.weights.h5
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0070 - val_loss: 0.0032 - learning_rate: 1.2500e-04
# Epoch 38/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0068
# Epoch 38: val_loss did not improve from 0.00319
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0067 - val_loss: 0.0032 - learning_rate: 1.2500e-04
# Epoch 39/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0070
# Epoch 39: val_loss did not improve from 0.00319
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0069 - val_loss: 0.0032 - learning_rate: 1.2500e-04
# Epoch 40/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0070
# Epoch 40: val_loss did not improve from 0.00319
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0070 - val_loss: 0.0032 - learning_rate: 1.2500e-04
# Epoch 41/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0070
# Epoch 41: val_loss did not improve from 0.00319
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0069 - val_loss: 0.0032 - learning_rate: 1.2500e-04
# Epoch 42/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0072
# Epoch 42: val_loss did not improve from 0.00319
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0071 - val_loss: 0.0032 - learning_rate: 6.2500e-05
# Epoch 43/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0068
# Epoch 43: val_loss did not improve from 0.00319
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0068 - val_loss: 0.0032 - learning_rate: 6.2500e-05
# Epoch 44/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0069
# Epoch 44: val_loss did not improve from 0.00319
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0069 - val_loss: 0.0032 - learning_rate: 6.2500e-05
# Epoch 45/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0068
# Epoch 45: val_loss did not improve from 0.00319
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0068 - val_loss: 0.0032 - learning_rate: 6.2500e-05
# Epoch 46/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0070
# Epoch 46: val_loss improved from 0.00319 to 0.00318, saving model to best_bilstm_Seoul.weights.h5
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0069 - val_loss: 0.0032 - learning_rate: 6.2500e-05
# Epoch 47/50
# 97/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0068
# Epoch 47: val_loss did not improve from 0.00318
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0068 - val_loss: 0.0032 - learning_rate: 3.1250e-05
# Epoch 48/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0069
# Epoch 48: val_loss did not improve from 0.00318
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0069 - val_loss: 0.0032 - learning_rate: 3.1250e-05
# Epoch 49/50
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0068
# Epoch 49: val_loss did not improve from 0.00318
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.0068 - val_loss: 0.0032 - learning_rate: 3.1250e-05
# Epoch 50/50
# 96/99 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0069
# Epoch 50: val_loss did not improve from 0.00318
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0068 - val_loss: 0.0032 - learning_rate: 3.1250e-05
# Restoring model weights from the end of the best epoch: 46.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
# MAE: 0.0352, RMSE: 0.0555, SMAPE: 21.51%, Accuracy: 78.49%
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 1/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.0761 - val_loss: 0.0138 - learning_rate: 0.0010
# Epoch 2/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0210 - val_loss: 0.0139 - learning_rate: 0.0010
# Epoch 3/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0210 - val_loss: 0.0139 - learning_rate: 0.0010
# Epoch 4/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0206 - val_loss: 0.0139 - learning_rate: 0.0010
# Epoch 5/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0204 - val_loss: 0.0138 - learning_rate: 0.0010
# Epoch 6/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0202 - val_loss: 0.0140 - learning_rate: 0.0010
# Epoch 7/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0198 - val_loss: 0.0131 - learning_rate: 5.0000e-04
# Epoch 8/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0198 - val_loss: 0.0131 - learning_rate: 5.0000e-04
# Epoch 9/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0197 - val_loss: 0.0131 - learning_rate: 5.0000e-04
# Epoch 10/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0197 - val_loss: 0.0131 - learning_rate: 5.0000e-04
# Epoch 11/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0196 - val_loss: 0.0131 - learning_rate: 5.0000e-04
# Epoch 12/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0196 - val_loss: 0.0131 - learning_rate: 5.0000e-04
# Epoch 13/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0195 - val_loss: 0.0127 - learning_rate: 2.5000e-04
# Epoch 14/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0192 - val_loss: 0.0127 - learning_rate: 2.5000e-04
# Epoch 15/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0196 - val_loss: 0.0126 - learning_rate: 2.5000e-04
# Epoch 16/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0197 - val_loss: 0.0126 - learning_rate: 2.5000e-04
# Epoch 17/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0194 - val_loss: 0.0126 - learning_rate: 2.5000e-04
# Epoch 18/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0196 - val_loss: 0.0126 - learning_rate: 2.5000e-04
# Epoch 19/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0194 - val_loss: 0.0126 - learning_rate: 1.2500e-04
# Epoch 20/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0193 - val_loss: 0.0126 - learning_rate: 1.2500e-04
# Epoch 21/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0194 - val_loss: 0.0125 - learning_rate: 1.2500e-04
# Epoch 22/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0193 - val_loss: 0.0125 - learning_rate: 1.2500e-04
# Epoch 23/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0194 - val_loss: 0.0125 - learning_rate: 1.2500e-04
# Epoch 24/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0194 - val_loss: 0.0125 - learning_rate: 1.2500e-04
# Epoch 25/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0193 - val_loss: 0.0125 - learning_rate: 1.2500e-04
# Epoch 26/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0193 - val_loss: 0.0124 - learning_rate: 6.2500e-05
# Epoch 27/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0193 - val_loss: 0.0124 - learning_rate: 6.2500e-05
# Epoch 28/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0191 - val_loss: 0.0124 - learning_rate: 6.2500e-05
# Epoch 29/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0194 - val_loss: 0.0124 - learning_rate: 6.2500e-05
# Epoch 30/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0192 - val_loss: 0.0124 - learning_rate: 6.2500e-05
# Epoch 31/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0191 - val_loss: 0.0124 - learning_rate: 6.2500e-05
# Epoch 32/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0193 - val_loss: 0.0124 - learning_rate: 3.1250e-05
# Epoch 33/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0193 - val_loss: 0.0124 - learning_rate: 3.1250e-05
# Epoch 34/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0193 - val_loss: 0.0123 - learning_rate: 3.1250e-05
# Epoch 35/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0192 - val_loss: 0.0124 - learning_rate: 3.1250e-05
# Epoch 36/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0194 - val_loss: 0.0124 - learning_rate: 3.1250e-05
# Epoch 37/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0191 - val_loss: 0.0123 - learning_rate: 1.5625e-05
# Epoch 38/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0192 - val_loss: 0.0123 - learning_rate: 1.5625e-05
# Epoch 39/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0192 - val_loss: 0.0123 - learning_rate: 1.5625e-05
# Epoch 40/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0191 - val_loss: 0.0123 - learning_rate: 1.5625e-05
# Epoch 41/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0193 - val_loss: 0.0123 - learning_rate: 1.5625e-05
# Epoch 42/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0191 - val_loss: 0.0123 - learning_rate: 7.8125e-06
# Epoch 43/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0192 - val_loss: 0.0123 - learning_rate: 7.8125e-06
# Epoch 44/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0191 - val_loss: 0.0123 - learning_rate: 7.8125e-06
# Epoch 45/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0191 - val_loss: 0.0123 - learning_rate: 7.8125e-06
# Epoch 46/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0191 - val_loss: 0.0123 - learning_rate: 7.8125e-06
# Epoch 47/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0196 - val_loss: 0.0123 - learning_rate: 3.9063e-06
# Epoch 48/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0191 - val_loss: 0.0123 - learning_rate: 3.9063e-06
# Epoch 49/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0191 - val_loss: 0.0123 - learning_rate: 3.9063e-06
# Epoch 50/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0193 - val_loss: 0.0123 - learning_rate: 3.9063e-06
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
#
# 📊 Hybrid Prophet-LSTM - Mashhad
# MAE: 0.0756, RMSE: 0.1027, SMAPE: 6.51%, Accuracy: 93.49%
# Epoch 1/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - loss: 0.0182 - val_loss: 0.0063 - learning_rate: 0.0010
# Epoch 2/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0112 - val_loss: 0.0058 - learning_rate: 0.0010
# Epoch 3/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0108 - val_loss: 0.0054 - learning_rate: 0.0010
# Epoch 4/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0101 - val_loss: 0.0047 - learning_rate: 0.0010
# Epoch 5/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0094 - val_loss: 0.0041 - learning_rate: 0.0010
# Epoch 6/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0086 - val_loss: 0.0037 - learning_rate: 0.0010
# Epoch 7/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0078 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 8/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0074 - val_loss: 0.0031 - learning_rate: 0.0010
# Epoch 9/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0071 - val_loss: 0.0029 - learning_rate: 0.0010
# Epoch 10/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0065 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 11/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0065 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 12/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0064 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 13/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0064 - val_loss: 0.0027 - learning_rate: 0.0010
# Epoch 14/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0060 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 15/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0059 - val_loss: 0.0028 - learning_rate: 0.0010
# Epoch 16/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0059 - val_loss: 0.0029 - learning_rate: 5.0000e-04
# Epoch 17/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0058 - val_loss: 0.0029 - learning_rate: 5.0000e-04
# Epoch 18/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0059 - val_loss: 0.0028 - learning_rate: 5.0000e-04
# Epoch 19/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0058 - val_loss: 0.0028 - learning_rate: 5.0000e-04
# Epoch 20/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0056 - val_loss: 0.0030 - learning_rate: 5.0000e-04
# Epoch 21/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0058 - val_loss: 0.0027 - learning_rate: 2.5000e-04
# Epoch 22/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0056 - val_loss: 0.0027 - learning_rate: 2.5000e-04
# Epoch 23/50
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0057 - val_loss: 0.0028 - learning_rate: 2.5000e-04
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step
#
# 📊 Hybrid Prophet-LSTM - Seoul
# MAE: 0.0402, RMSE: 0.0574, SMAPE: 24.55%, Accuracy: 75.45%
# ==== Mashhad - Linear Regression ====
#   Pollution Level       MAE  SMAPE (%)  Accuracy (%)
# 0             Low  0.067512   6.307149     93.692851
# 1          Medium  0.027839   2.483692     97.516308
# 2            High  0.101443   8.212118     91.787882
#
# ==== Seoul - Linear Regression ====
#   Pollution Level       MAE  SMAPE (%)  Accuracy (%)
# 0             Low  0.034928  32.900589     67.099411
# 1          Medium  0.024772  14.728185     85.271815
# 2            High  0.044749  15.824545     84.175455
#
# ==== Mashhad - Prophet ====
#   Pollution Level       MAE  SMAPE (%)  Accuracy (%)
# 0             Low  0.098337   9.015667     90.984333
# 1          Medium  0.033591   2.952259     97.047741
# 2            High  0.101559   8.220676     91.779324
#
# ==== Seoul - Prophet ====
#   Pollution Level       MAE  SMAPE (%)  Accuracy (%)
# 0             Low  0.087243  65.401056     34.598944
# 1          Medium  0.044225  24.098315     75.901685
# 2            High  0.070816  25.619832     74.380168
#
# ==== Mashhad - LSTM ====
#   Pollution Level       MAE  SMAPE (%)  Accuracy (%)
# 0             Low  0.079448   7.394822     92.605179
# 1          Medium  0.027314   2.415751     97.584251
# 2            High  0.108232   8.786192     91.213806
#
# ==== Seoul - LSTM ====
#   Pollution Level       MAE  SMAPE (%)  Accuracy (%)
# 0             Low  0.036531  34.259903     65.740097
# 1          Medium  0.028213  16.960340     83.039658
# 2            High  0.043062  15.399533     84.600464
#
# ==== Mashhad - Bi-LSTM ====
#   Pollution Level       MAE  SMAPE (%)  Accuracy (%)
# 0             Low  0.066943   6.263104     93.736893
# 1          Medium  0.024779   2.203179     97.796822
# 2            High  0.102516   8.302136     91.697861
#
# ==== Seoul - Bi-LSTM ====
#   Pollution Level       MAE  SMAPE (%)  Accuracy (%)
# 0             Low  0.034684  32.811352     67.188644
# 1          Medium  0.027333  16.541576     83.458420
# 2            High  0.043200  15.649208     84.350792
#
# ==== Mashhad - TCN ====
#   Pollution Level       MAE  SMAPE (%)  Accuracy (%)
# 0             Low  0.063788   5.974649     94.025352
# 1          Medium  0.025009   2.228309     97.771690
# 2            High  0.104031   8.433820     91.566177
#
# ==== Seoul - TCN ====
#   Pollution Level       MAE  SMAPE (%)  Accuracy (%)
# 0             Low  0.033348  30.277840     69.722160
# 1          Medium  0.030340  17.929651     82.070351
# 2            High  0.040714  14.370218     85.629784
#
# ==== Mashhad - Hybrid Prophet-LSTM ====
#   Pollution Level       MAE  SMAPE (%)  Accuracy (%)
# 0             Low  0.090352   8.322264     91.677736
# 1          Medium  0.031244   2.754620     97.245380
# 2            High  0.099782   8.062821     91.937179
#
# ==== Seoul - Hybrid Prophet-LSTM ====
#   Pollution Level       MAE  SMAPE (%)  Accuracy (%)
# 0             Low  0.046894  41.623933     58.376067
# 1          Medium  0.030192  17.270867     82.729133
# 2            High  0.043468  15.459141     84.540859

# %%
import pandas as pd
import numpy as np
from prophet import Prophet
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = pd.read_csv("Mashhad_CO_Median.csv")

df["Date"] = pd.to_datetime(df["Date"], errors="coerce")
data = df[["Date", "CO"]].rename(columns={"Date": "ds", "CO": "y"})
data = data.groupby("ds").mean().reset_index()
data = data.dropna().reset_index(drop=True)

split = int(len(data) * 0.8)
train = data.iloc[:split]
test  = data.iloc[split:].reset_index(drop=True)

model = Prophet(daily_seasonality=True, yearly_seasonality=True)
model.fit(train)

future = test[["ds"]]
forecast = model.predict(future)

y_test_values = test["y"].values
y_pred_values = forecast["yhat"].values

# %%
import numpy as np
results = []

horizons = {
    "5 Days": (5, 1),
    "15 Days": (15, 2),
    "1 Month": (30, 5),
    "6 Months": (180, 10),
    "1 Year": (365, 15)
}

mean_y = np.mean(y_test_values)

for name, (day, window) in horizons.items():
    if day + window >= len(y_test_values):
        continue

    start = max(0, day - window - 1)
    end   = min(len(y_test_values), day + window)

    y_true_h = y_test_values[start:end]
    y_pred_h = y_pred_values[start:end]

    mae = mean_absolute_error(y_true_h, y_pred_h)
    rmse = np.sqrt(mean_squared_error(y_true_h, y_pred_h))

    accuracy = 100 * (1 - mae / mean_y)

    results.append({
        "Time": name,
        "MAE": round(mae, 3),
        "RMSE": round(rmse, 3),
        "Accuracy (%)": round(accuracy, 2)
    })

# %%
fig, axes = plt.subplots(1, 3, figsize=(18,5))

models = ["Linear Reg.", "Prophet", "LSTM", "Bi-LSTM", "TCN", "Prophet-LSTM"]
mae = [0.0675, 0.0794, 0.0676, 0.0663, 0.0675, 0.0699]
rmse = [0.0981, 0.1065, 0.0990, 0.0981, 0.0986, 0.0976]
smape = [5.81, 6.84, 5.81, 5.70, 5.81, 6.02]

axes[0].bar(models, mae)
axes[0].set_title("(a) MAE")
axes[0].set_ylabel("MAE (mg/m³)")
axes[0].tick_params(axis='x', rotation=20)

axes[1].bar(models, rmse)
axes[1].set_title("(b) RMSE")
axes[1].set_ylabel("RMSE (mg/m³)")
axes[1].tick_params(axis='x', rotation=20)

axes[2].bar(models, smape)
axes[2].set_title("(c) SMAPE")
axes[2].set_ylabel("SMAPE (%)")
axes[2].tick_params(axis='x', rotation=20)

for ax in axes:
    ax.grid(axis="y", alpha=0.3)

plt.suptitle("Comparison of prediction errors for different models (Mashhad dataset)")
plt.tight_layout()
plt.savefig("model_comparison_separate.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

# Residuals
residuals = y_test_inv.flatten() - y_pred_inv.flatten()

plt.figure(figsize=(7,5))
plt.hist(residuals, bins=30, edgecolor='black')

plt.xlabel("Residual (Actual − Predicted)")
plt.ylabel("Frequency")
plt.title("Histogram of Prediction Residuals")

plt.grid(alpha=0.3)

plt.tight_layout()
plt.savefig("Figure6_Residual_Histogram.png", dpi=600)
plt.show()

# %%
# %whos
# Out:
# Variable              Type         Data/Info
# --------------------------------------------
# Adam                  type         <class 'keras.src.optimizers.adam.Adam'>
# Bidirectional         type         <class 'keras.src.layers.<...>rectional.Bidirectional'>
# Conv1D                type         <class 'keras.src.layers.<...>olutional.conv1d.Conv1D'>
# Dense                 type         <class 'keras.src.layers.core.dense.Dense'>
# Dropout               type         <class 'keras.src.layers.<...>ization.dropout.Dropout'>
# EarlyStopping         type         <class 'keras.src.callbac<...>_stopping.EarlyStopping'>
# Flatten               type         <class 'keras.src.layers.<...>shaping.flatten.Flatten'>
# Input                 function     <function Input at 0x7e3785a10cc0>
# LSTM                  type         <class 'keras.src.layers.rnn.lstm.LSTM'>
# LinearRegression      ABCMeta      <class 'sklearn.linear_mo<...>._base.LinearRegression'>
# MinMaxScaler          type         <class 'sklearn.preproces<...>sing._data.MinMaxScaler'>
# ModelCheckpoint       type         <class 'keras.src.callbac<...>ckpoint.ModelCheckpoint'>
# Prophet               type         <class 'prophet.forecaster.Prophet'>
# ReduceLROnPlateau     type         <class 'keras.src.callbac<...>ateau.ReduceLROnPlateau'>
# SEED                  int          42
# Sequential            type         <class 'keras.src.models.sequential.Sequential'>
# SpatialDropout1D      type         <class 'keras.src.layers.<...>ropout.SpatialDropout1D'>
# ax                    Axes         Axes(0.775425,0.0800772;0.207368x0.859865)
# axes                  ndarray      3: 3 elems, type `object`, 24 bytes
# best_value            float64      5.7
# calculate_smape       function     <function calculate_smape at 0x7e37fc2bd1c0>
# decimals              int          2
# fig                   Figure       Figure(1250x580)
# hybrid_prophet_lstm   function     <function hybrid_prophet_lstm at 0x7e376b562f20>
# mae                   ndarray      6: 6 elems, type `float64`, 48 bytes
# mean_absolute_error   function     <function mean_absolute_error at 0x7e37ff7ea3e0>
# mean_squared_error    function     <function mean_squared_error at 0x7e37ff7ea7a0>
# metric_name           str          SMAPE
# metrics               list         n=3
# models                list         n=6
# np                    module       <module 'numpy' from '/us<...>kages/numpy/__init__.py'>
# order                 ndarray      6: 6 elems, type `int64`, 48 bytes
# os                    module       <module 'os' (frozen)>
# pd                    module       <module 'pandas' from '/u<...>ages/pandas/__init__.py'>
# plt                   module       <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# random                module       <module 'random' from '/u<...>ib/python3.12/random.py'>
# res_mashhad_bilstm    dict         n=7
# res_mashhad_hybrid    dict         n=8
# res_mashhad_lr        dict         n=8
# res_mashhad_lstm      dict         n=7
# res_mashhad_prophet   dict         n=8
# res_mashhad_tcn       dict         n=12
# res_seoul_bilstm      dict         n=7
# res_seoul_hybrid      dict         n=8
# res_seoul_lr          dict         n=8
# res_seoul_lstm        dict         n=7
# res_seoul_prophet     dict         n=8
# res_seoul_tcn         dict         n=12
# res_uni               dict         n=12
# results_df            DataFrame          City       MAE     <...>-> MAE: 0.0388, RMSE...
# rmse                  ndarray      6: 6 elems, type `float64`, 48 bytes
# run_bilstm            function     <function run_bilstm at 0x7e3769c0dc60>
# run_linear_no_leak    function     <function run_linear_no_leak at 0x7e37ff016840>
# run_lstm              function     <function run_lstm at 0x7e377ad951c0>
# run_prophet           function     <function run_prophet at 0x7e37f3a35d00>
# run_tcn               function     <function run_tcn at 0x7e3769c0c0e0>
# smape                 ndarray      6: 6 elems, type `float64`, 48 bytes
# sorted_models         ndarray      6: 6 elems, type `<U17`, 408 bytes
# sorted_values         ndarray      6: 6 elems, type `float64`, 48 bytes
# tf                    module       <module 'tensorflow' from<...>/tensorflow/__init__.py'>
# value                 float64      6.84
# values                ndarray      6: 6 elems, type `float64`, 48 bytes
# x_range               float64      1.1399999999999997
# xlabel                str          SMAPE (%)
# y                     ndarray      6: 6 elems, type `int64`, 48 bytes
# yi                    int64        5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

model_names = [
    "Linear Regression",
    "Prophet",
    "LSTM",
    "Bi-LSTM",
    "TCN",
    "Prophet-LSTM"
]

results = pd.DataFrame({
    "Model": model_names,
    "MAE": [
        res_mashhad_lr["MAE"],
        res_mashhad_prophet["MAE"],
        res_mashhad_lstm["MAE"],
        res_mashhad_bilstm["MAE"],
        res_mashhad_tcn["MAE"],
        res_mashhad_hybrid["MAE"]
    ],
    "RMSE": [
        res_mashhad_lr["RMSE"],
        res_mashhad_prophet["RMSE"],
        res_mashhad_lstm["RMSE"],
        res_mashhad_bilstm["RMSE"],
        res_mashhad_tcn["RMSE"],
        res_mashhad_hybrid["RMSE"]
    ],
    "SMAPE": [
        res_mashhad_lr["SMAPE"],
        res_mashhad_prophet["SMAPE"],
        res_mashhad_lstm["SMAPE"],
        res_mashhad_bilstm["SMAPE"],
        res_mashhad_tcn["SMAPE"],
        res_mashhad_hybrid["SMAPE"]
    ],
    "Accuracy": [
        res_mashhad_lr["Accuracy"],
        res_mashhad_prophet["Accuracy"],
        res_mashhad_lstm["Accuracy"],
        res_mashhad_bilstm["Accuracy"],
        res_mashhad_tcn["Accuracy"],
        res_mashhad_hybrid["Accuracy"]
    ]
})


model_colors = [
    "#4C78A8",  # Linear Regression
    "#F58518",  # Prophet
    "#54A24B",  # LSTM
    "#E45756",  # Bi-LSTM
    "#72B7B2",  # TCN
    "#B279A2"   # Prophet-LSTM
]

fig, axes = plt.subplots(
    2, 2,
    figsize=(15, 10),
    dpi=150
)

axes = axes.flatten()

metric_info = [
    ("MAE", "MAE", "(a)"),
    ("RMSE", "RMSE", "(b)"),
    ("SMAPE", "SMAPE (%)", "(c)"),
    ("Accuracy", "Accuracy (%)", "(d)")
]

x = np.arange(len(model_names))

for ax, (metric, ylabel, panel_label) in zip(axes, metric_info):

    values = results[metric].values

    # --------------------------------------------------------
    # Find best model
    # --------------------------------------------------------

    if metric == "Accuracy":
        best_idx = np.argmax(values)
    else:
        best_idx = np.argmin(values)


    bars = ax.bar(
        x,
        values,
        width=0.68,
        color=model_colors,
        edgecolor="black",
        linewidth=0.7
    )

    # Highlight best model
    bars[best_idx].set_linewidth(2.0)


    for i, (bar, value) in enumerate(zip(bars, values)):

        if metric in ["MAE", "RMSE"]:
            label = f"{value:.4f}"
        else:
            label = f"{value:.2f}"

        ax.text(
            bar.get_x() + bar.get_width() / 2,
            bar.get_height(),
            label,
            ha="center",
            va="bottom",
            fontsize=9,
            fontweight="bold" if i == best_idx else "normal"
        )


    ax.set_title(
        metric,
        fontsize=15,
        fontweight="bold",
        pad=10
    )

    ax.set_ylabel(
        ylabel,
        fontsize=11
    )

    ax.set_xticks(x)
    ax.set_xticklabels(
        model_names,
        rotation=25,
        ha="right",
        fontsize=9
    )


    ax.grid(
        axis="y",
        linestyle="--",
        linewidth=0.6,
        alpha=0.25
    )

    ax.set_axisbelow(True)

    ax.text(
        -0.10,
        1.04,
        panel_label,
        transform=ax.transAxes,
        fontsize=13,
        fontweight="bold",
        va="bottom"
    )


    max_value = max(values)

    if metric in ["MAE", "RMSE"]:
        ax.set_ylim(0, max_value * 1.18)

    elif metric == "SMAPE":
        ax.set_ylim(0, max_value * 1.18)

    elif metric == "Accuracy":
        ax.set_ylim(92, 95)

fig.suptitle(
    "Performance Comparison of CO Forecasting Models in Mashhad",
    fontsize=18,
    fontweight="bold",
    y=0.98
)

plt.tight_layout(
    rect=[0, 0, 1, 0.95],
    h_pad=2.5,
    w_pad=2.0
)

plt.savefig(
    "Figure_Comparison_Mashhad_600dpi.png",
    dpi=600,
    bbox_inches="tight"
)

plt.savefig(
    "Figure_Comparison_Mashhad.pdf",
    bbox_inches="tight"
)

plt.savefig(
    "Figure_Comparison_Mashhad.svg",
    bbox_inches="tight"
)

plt.show()
